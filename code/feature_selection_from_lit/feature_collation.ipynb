# %%
import numpy as np
import pandas as pd
import copy
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import json
import joblib
import optuna

# %% [markdown]
# ### Feature Gathering

# %% [markdown]
# https://jmai.amegroups.org/article/view/8590/html
#
# Paper suggests the following are important factors to reducing maternal mortality:
# - birth control measures/family planning with related reproductive health services
# - pregnancy complications management or skilled care during pregnancy and childbirth
# - medication of pregnant women with timely emergency obstetric care
# - post-immunisations complications focus
# - IUCD
# - nutrition deficiency

# %% [markdown]
# https://www.sciencedirect.com/science/article/pii/S0169023X23000587?pes=vor&utm_source=scopus&getft_integrator=scopus#sec5
#
# - high BMI
# - max, mean, min elevation (defines reachibility of area)
# - proportion of population living with sanitation, electricity, and clean fuel for cooking
# - percentage of mothers taking iron folic acid for 100 days (to prevent anemia)
# - average out-of-pocket spending per birth in a public facility
# - percentage of women who married when they were under 18
# - total population sex ratio adn newborn sex ratio (for demographic information)
# - health insurance/financial covereage
# - proportion of C-section births
# - percentage of institutional births in a public facility
# - health facilities available

# %% [markdown]
# https://www.thelancet.com/action/showPdf?pii=S2214-109X%2823%2900468-0
#
# - safe abortion
# - modern contraception
# - antenatal, intrapartum, and postpartum care
# - pre-existing medical conditions
# - climate/eco-system
# - economic, political, and cultural bases of societies
# (eg, health insurance policies and health budgetary
# allocations, health-care policies and legislations on
# reproductive rights and access to care, societal norms
# and expectations related to gender roles and cultural
# beliefs surrounding pregnancy and childbirth).
# - social determinants of health are the
# conditions in which women are born, grow, work, and live
# before pregnancy, and during pregnancy, childbirth, and
# the postpartum period
# - exposure to external agents (eg,
# physical, chemical, and biological hazards, infections,
# accidents, and violence)
# - pregnancies < 18 or > 35
# - existing conditions
# - violence against women
# - nutrition deficiency, substance abuse, etc.
#
#
# measured:
# - skilled birth attendance
# - fertility rate
# - life expectancy
# - neonatal mortality rate
# - universal health coverage
# - human development index
# - Risk of impoverishing expend for surgical care
# - Antenatal care coverage (four visits)
# - cesaerean section rate
# - Gender inequality index
# - Gini in equality

# %% [markdown]
# https://iris.who.int/bitstream/handle/10665/381012/9789240108462-eng.pdf?sequence=1
#
# - haemorrhage
# - hypertensive disorders (pre-existing and during pregnancy)
# - complications of unsafe abortion
# - noncommunicable diseases and pre-exiting conditions
#     Gestational diabetes is the most common medical
#     disorder in pregnancy (28). Other NCDs commonly
#     experienced by pregnant women include asthma,
#     cardiac conditions, epilepsy, haemoglobinopathies,
#     and mental health and substance use condition
# - social determinants of health, such as education, ethnicity, race, gender and income
# - harmful gender norms, biases and inequalities that obstruct the rights of women and girls
# - weak health systems that lack adequately trained and competent health workers and essential medical supplies, providing poor quality care with little accountability
# - external factors, such as climate change, conflict and humanitarian crises, which cause instability and fragility
# - HIV

# %%
merged_data_1985 = pd.DataFrame(pd.read_pickle('../../raw_merged_data_v2_withinyears'))
merged_relevant = merged_data_1985[merged_data_1985['date'] > 1984]
merged_relevant = merged_relevant[merged_relevant['date'] < 2019]
merged_relevant = merged_relevant.drop(['Maternal mortality ratio (modeled estimate, per 100,000 live births)', 'Lifetime risk of maternal death (1 in: rate varies by country)', 'Lifetime risk of maternal death (%)', 'Number of maternal deaths'], axis=1)
merged_features = merged_relevant.drop(columns=['Maternal mortality ratio (national estimate, per 100,000 live births)'], axis=1)

# %%
useful_features = ['date', 'setting', 'Women participating in own health care decisions (% of women age 15-49)',
                   'Women and girls who use menstrual materials (% of women and girls ages 15-49 who had a menstrual period within the last year)',
                   'Mortality rate, infant (per 1,000 live births)', 'Female genital mutilation prevalence (%)',
                   'Pregnant women receiving prenatal care (%)', 'Knowledge of any method of contraception (% of all women ages 15-49)',
                   'Demand for family planning satisfied by any methods (% of married women with demand for family planning)',
                   'Unmet need for contraception (% of married women ages 15-49)', 'Pregnant women receiving prenatal care of at least four visits (% of pregnant women)',
                   'Decision maker about a woman\'s own health care: someone else (% of women age 15-49)',
                    "Women\'s share of population ages 15+ living with HIV (%)", 
                    'Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)', "Births attended by skilled health staff (% of total)",
                    "Prevalence of overweight (% of adults)", "Survival to age 65, female (% of cohort)", 
                    "Stillbirth rate (per 1,000 total births)", "Prevalence of anemia among pregnant women (%)",
                    "Fertility rate, total (births per woman)", 
                    "Women with high empowerment in the attitude to violence domain (%) Quintile 1 (poorest)",
                    "1.0.0 Communicable, maternal, neonatal, and nutritional diseases prevalence (age standardized) (per 100 000 population) female",
                    "1.D.0 Neglected tropical diseases and malaria prevalence (age standardized) (per 100 000 population) female",
                    "1.F.0 Maternal and neonatal disorders prevalence (age standardized) (per 100 000 population) female",
                    "1.G.0 Nutritional deficiencies prevalence (age standardized) (per 100 000 population) female",
                    "2.0.0 Non-communicable diseases prevalence (age standardized) (per 100 000 population) female",
                    "2.G.0 Substance use disorders prevalence (age standardized) (per 100 000 population) female",
                    "3.B.06 Adverse effects of medical treatment prevalence (age standardized) (per 100 000 population) female",
                    "3.C.0 Self-harm and interpersonal violence prevalence (age standardized) (per 100 000 population) female",
                    "3.B.10 Exposure to forces of nature prevalence (age standardized) (per 100 000 population) female",
                    "3.C.04 Conflict and terrorism prevalence (age standardized) (per 100 000 population) female",
                    "School enrollment, secondary (% net) female", "Literacy rate, adult total (% of people ages 15 and above) female",
                    "income_num", "Borrowed for health or medical purposes (% age 15+)",
                    "2.B.04 Hypertensive heart disease prevalence (age standardized) (per 100 000 population) female",
                    "2.H.0 Diabetes and kidney diseases prevalence (age standardized) (per 100 000 population) female",
                    "Probability of Survival to Age 5",
                    "Population living in areas where elevation is below 5 meters (% of total population) rural",
                    "Coverage of social safety net programs (% of population) Quintile 1 (poorest)"
                   ]

# %%
len(useful_features)
# Out:
# 40

# %%
for feature in merged_features.columns:
    print(feature)
# Out:
# date
# Women and girls who use menstrual materials (% of women and girls ages 15-49 who had a menstrual period within the last year)
# setting
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14 (% of population ages 5-14)
# Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4 (% of population ages 0-4)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+ (% of population ages 60+)
# Women participating in own health care decisions (% of women age 15-49)
# Antiretroviral therapy coverage (% of adult males living with HIV)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+, male (% of male population ages 60+)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-24, male (2 prevent ways and reject 3 misconceptions)
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)
# Mortality rate, infant (per 1,000 live births)
# Female genital mutilation prevalence (%)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59 (% of population ages 15-59)
# Cause of death, by injury, ages 15-59, female (% of female population ages 15-59)
# Borrowed for health or medical purposes (% age 15+)
# Prevalence of current tobacco use, females (% of female adults)
# Survival to age 65, female (% of cohort)
# Pregnant women receiving prenatal care (%)
# Mortality rate attributed to unintentional poisoning (per 100,000 population)
# Knowledge of any method of contraception (% of all women ages 15-49)
# Fertility planning status: mistimed pregnancy (% of births)
# Cause of death, by non-communicable diseases, ages 60+ (% of population ages 60+)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)
# Demand for family planning satisfied by any methods (% of married women with demand for family planning)
# Number of infant deaths, male
# Cause of death, by non-communicable diseases, ages 0-4 (% of population ages 0-4)
# Cause of death, by non-communicable diseases, ages 0-4, male (% of male population ages 0-4)
# Prevalence of underweight, weight for age (% of children under 5)
# Cause of death, by non-communicable diseases, ages 15-59, female (% of female population ages 15-59)
# Unmet need for contraception (% of married women ages 15-49)
# Mortality rate, under-5, male (per 1,000 live births)
# Knowledge of any modern method of contraception (% of all women ages 15-49)
# Prevalence of overweight, weight for height, male (% of children under 5)
# Pregnant women receiving prenatal care of at least four visits (% of pregnant women)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59, male (% of male population ages 15-59)
# Decision maker about a woman's own health care: mainly wife  (% of women age 15-49)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4, female (% of female population ages 0-4)
# Female genital mutilation prevalence (%): Q5 (highest)
# Women participating in none of the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# Cause of death, by injury, ages 5-14, male (% of male population ages 5-14)
# Incidence of HIV, ages 15-49, male (per 1,000 uninfected male population ages 15-49)
# Prevalence of severe wasting, weight for height (% of children under 5)
# Prevalence of HIV, female (% ages 15-24)
# Cause of death, by non-communicable diseases, ages 5-14, male (% of male population ages 5-14)
# Mortality caused by road traffic injury, female (per 100,000 female population)
# Suicide mortality rate, female (per 100,000 female population)
# Women's share of population ages 15+ living with HIV (%)
# Mortality caused by road traffic injury (per 100,000 population)
# Cause of death, by non-communicable diseases, male (% of male population)
# Probability of Survival to Age 5, Male
# Women and girls who participate in activities during menstrual period, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Cause of death, by injury (% of total)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-49, male (2 prevent ways and reject 3 misconceptions)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, male (% of male population)
# Cause of death, by injury, ages 5-14, female (% of female population ages 5-14)
# Knowledge of any modern method of contraception  (% of married men)
# Mortality rate, adult, male (per 1,000 male adults)
# Prevalence of underweight, weight for age, male (% of children under 5)
# Cause of death, by injury, ages 60+ (% of population ages 60+)
# Cause of death, by injury, ages 60+, female (% of female population ages 60+)
# Knowledge of any method of contraception (% of all men)
# Decision maker about a woman's own health care: wife and husband jointly (% of women age 15-49)
# Incidence of HIV, ages 15-24, male (per 1,000 uninfected male population ages 15-24)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)
# Cause of death, by injury, ages 15-59 (% of population ages 15-59)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+, female (% of female population ages 60+)
# Prevalence of stunting, height for age (% of children under 5)
# Prevalence of anemia among non-pregnant women (% of women ages 15-49)
# Women and girls who use menstrual materials, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)
# Women and girls who participate in activities during menstrual period (% of women and girls ages 15-49 who had a menstrual period within the last year)
# Fraction of Children Under 5 Not Stunted, Male
# Survival to age 65, male (% of cohort)
# Condom use at last high-risk sex, adult female (% ages 15-49)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-24, female (2 prevent ways and reject 3 misconceptions)
# Borrowed for health or medical purposes, female (% age 15+)
# Borrowed for health or medical purposes, male (% age 15+)
# Prevalence of overweight, female (% of female adults)
# Knowledge of any modern method of contraception (% of married women ages 15-49)
# Cause of death, by non-communicable diseases, ages 5-14, female (% of female population ages 5-14)
# Female genital mutilation prevalence (%): Q1 (lowest)
# Cause of death, by non-communicable diseases, ages 15-59 (% of population ages 15-59)
# Cause of death, by non-communicable diseases, ages 5-14 (% of population ages 5-14)
# Cause of death, by non-communicable diseases, female (% of female population)
# Cause of death, by injury, female (% of female population)
# Mortality rate, infant, female (per 1,000 live births)
# Cause of death, by injury, ages 5-14 (% of population ages 5-14)
# Knowledge of any modern method of contraception  (% of all men)
# Contraceptive prevalence, any modern method (% of married women ages 15-49)
# Prevalence of stunting, height for age, female (% of children under 5)
# Prevalence of syphilis (% of women attending antenatal care)
# Prevalence of current tobacco use (% of adults)
# Women and girls who participate in activities during menstrual period, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Adolescent fertility rate (births per 1,000 women ages 15-19)
# Prevalence of wasting, weight for height (% of children under 5)
# Knowledge of any method of contraception (% of married men)
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care  (% of women age 15-49)
# People practicing open defecation, rural (% of rural population)
# Number of under-five deaths, male
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene, female (per 100,000 female population)
# Probability of Survival to Age 5, Female
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59, female (% of female population ages 15-59)
# Women and girls who have private places to wash and change during menstrual period, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Number of infant deaths, female
# Births attended by skilled health staff (% of total)
# Prevalence of overweight (% of adults)
# Suicide mortality rate, male (per 100,000 male population)
# Condom use at last high-risk sex, adult male (% ages 15-49)
# Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)
# Mortality rate, under-5, female (per 1,000 live births)
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14, male (% of male population ages 5-14)
# Prevalence of overweight, male (% of male adults)
# Fraction of Children Under 5 Not Stunted
# Survival Rate from Age 15-60, Female
# Women and girls who use menstrual materials, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Prevalence of overweight, weight for height (% of children under 5)
# Stillbirth rate (per 1,000 total births)
# Women and girls who have private places to wash and change during menstrual period (% of women and girls ages 15-49 who had a menstrual period within the last year)
# Cause of death, by non-communicable diseases, ages 15-59, male (% of male population ages 15-59)
# Female genital mutilation prevalence (%): Q2
# Wanted fertility rate (births per woman)
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene, male (per 100,000 male population)
# Fertility planning status: unwanted pregnancy (% of births)
# Mortality rate, infant, male (per 1,000 live births)
# Prevalence of anemia among women of reproductive age (% of women ages 15-49)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, female (% of female population)
# Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)
# Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)
# Cause of death, by non-communicable diseases (% of total)
# Decision maker about a woman's own health care: other (% of women age 15-49)
# Immunization, DPT (% of children ages 12-23 months)
# Incidence of HIV, ages 15-24, female (per 1,000 uninfected female population ages 15-24)
# Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# People practicing open defecation, urban (% of urban population)
# Cause of death, by non-communicable diseases, ages 60+, female (% of female population ages 60+)
# Prevalence of wasting, weight for height, male (% of children under 5)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)
# Cause of death, by injury, male (% of male population)
# Mortality rate, adult, female (per 1,000 female adults)
# Cause of death, by injury, ages 0-4, male (% of male population ages 0-4)
# Fertility rate, total (births per woman)
# Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)
# Decision maker about a woman's own health care: mainly husband (% of women age 15-49)
# Number of stillbirths
# Suicide mortality rate (per 100,000 population)
# Survival Rate from Age 15-60
# Knowledge of any method of contraception (% of married women ages 15-49)
# Prevalence of stunting, height for age, male (% of children under 5)
# Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)
# People practicing open defecation (% of population)
# Female genital mutilation prevalence (%): Q3
# Probability of Survival to Age 5
# Prevalence of obesity, female (% of female population ages 18+)
# Prevalence of severe wasting, weight for height, male (% of children under 5)
# Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)
# Cause of death, by injury, ages 0-4 (% of population ages 0-4)
# Number of infant deaths
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14, female (% of female population ages 5-14)
# Prevalence of severe wasting, weight for height, female (% of children under 5)
# Fertility planning status: planned pregnancy (% of births)
# Antiretroviral therapy coverage (% of adult females living with HIV)
# Cause of death, by injury, ages 15-59, male (% of male population ages 15-59)
# Prevalence of obesity, male (% of male population ages 18+)
# Demand for family planning satisfied by modern methods (% of married women with demand for family planning)
# Prevalence of HIV, male (% ages 15-24)
# Survival Rate from Age 15-60, Male
# Mortality caused by road traffic injury, male (per 100,000 male population)
# Prevalence of underweight, weight for age, female (% of children under 5)
# Immunization, measles (% of children ages 12-23 months)
# Contraceptive prevalence, any method (% of married women ages 15-49)
# Number of under-five deaths, female
# Prevalence of wasting, weight for height, female (% of children under 5)
# Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)
# Prevalence of anemia among pregnant women (%)
# Cause of death, by injury, ages 0-4, female (% of female population ages 0-4)
# Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)
# Mortality rate, under-5 (per 1,000 live births)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-49, female (2 prevent ways and reject 3 misconceptions)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4, male (% of male population ages 0-4)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)
# Decision maker about a woman's own health care: someone else (% of women age 15-49)
# Prevalence of overweight, weight for height, female (% of children under 5)
# Cause of death, by injury, ages 60+, male (% of male population ages 60+)
# Cause of death, by non-communicable diseases, ages 60+, male (% of male population ages 60+)
# Cause of death, by non-communicable diseases, ages 0-4, female (% of female population ages 0-4)
# Female genital mutilation prevalence (%): Q4
# Incidence of HIV, ages 15-49, female (per 1,000 uninfected female population ages 15-49)
# Fraction of Children Under 5 Not Stunted, Female
# Prevalence of current tobacco use, males (% of male adults)
# Women and girls who have private places to wash and change during menstrual period, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)
# Women with high empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with high empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with low empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with low empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with medium empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with high empowerment in the decision-making domain (%) Quintile 1 (poorest)
# Women with high empowerment in the decision-making domain (%) Quintile 5 (richest)
# Women with low empowerment in the decision-making  domain (%) Quintile 1 (poorest)
# Women with low empowerment in the decision-making  domain (%) Quintile 5 (richest)
# Women with medium empowerment in the decision-making domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the decision-making domain (%) Quintile 5 (richest)
# Women with high empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with high empowerment in the social independence domain (%) Quintile 5 (richest)
# Women with low empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with low empowerment in the social independence domain (%) Quintile 5 (richest)
# Women with medium empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the social independence domain (%) Quintile 5 (richest)
# 0.0.0 All causes prevalence (age standardized) (per 100 000 population) female
# 0.0.0 All causes prevalence (age standardized) (per 100 000 population) male
# 1.0.0 Communicable, maternal, neonatal, and nutritional diseases prevalence (age standardized) (per 100 000 population) female
# 1.0.0 Communicable, maternal, neonatal, and nutritional diseases prevalence (age standardized) (per 100 000 population) male
# 1.A.0 HIV/AIDS and sexually transmitted infections prevalence (age standardized) (per 100 000 population) female
# 1.A.0 HIV/AIDS and sexually transmitted infections prevalence (age standardized) (per 100 000 population) male
# 1.A.01 HIV/AIDS prevalence (age standardized) (per 100 000 population) female
# 1.A.01 HIV/AIDS prevalence (age standardized) (per 100 000 population) male
# 1.A.02 Sexually transmitted infections excluding HIV prevalence (age standardized) (per 100 000 population) female
# 1.A.02 Sexually transmitted infections excluding HIV prevalence (age standardized) (per 100 000 population) male
# 1.B.0 Respiratory infections and tuberculosis prevalence (age standardized) (per 100 000 population) female
# 1.B.0 Respiratory infections and tuberculosis prevalence (age standardized) (per 100 000 population) male
# 1.B.01 Tuberculosis prevalence (age standardized) (per 100 000 population) female
# 1.B.01 Tuberculosis prevalence (age standardized) (per 100 000 population) male
# 1.B.02 Lower respiratory infections prevalence (age standardized) (per 100 000 population) female
# 1.B.02 Lower respiratory infections prevalence (age standardized) (per 100 000 population) male
# 1.B.03 Upper respiratory infections prevalence (age standardized) (per 100 000 population) female
# 1.B.03 Upper respiratory infections prevalence (age standardized) (per 100 000 population) male
# 1.B.04 Otitis media prevalence (age standardized) (per 100 000 population) female
# 1.B.04 Otitis media prevalence (age standardized) (per 100 000 population) male
# 1.C.0 Enteric infections prevalence (age standardized) (per 100 000 population) female
# 1.C.0 Enteric infections prevalence (age standardized) (per 100 000 population) male
# 1.C.01 Diarrheal diseases prevalence (age standardized) (per 100 000 population) female
# 1.C.01 Diarrheal diseases prevalence (age standardized) (per 100 000 population) male
# 1.C.03 Typhoid and paratyphoid prevalence (age standardized) (per 100 000 population) female
# 1.C.03 Typhoid and paratyphoid prevalence (age standardized) (per 100 000 population) male
# 1.C.04 Invasive Non-typhoidal Salmonella (iNTS) prevalence (age standardized) (per 100 000 population) female
# 1.C.04 Invasive Non-typhoidal Salmonella (iNTS) prevalence (age standardized) (per 100 000 population) male
# 1.D.0 Neglected tropical diseases and malaria prevalence (age standardized) (per 100 000 population) female
# 1.D.0 Neglected tropical diseases and malaria prevalence (age standardized) (per 100 000 population) male
# 1.D.01 Malaria prevalence (age standardized) (per 100 000 population) female
# 1.D.01 Malaria prevalence (age standardized) (per 100 000 population) male
# 1.D.02 Chagas disease prevalence (age standardized) (per 100 000 population) female
# 1.D.02 Chagas disease prevalence (age standardized) (per 100 000 population) male
# 1.D.03 Leishmaniasis prevalence (age standardized) (per 100 000 population) female
# 1.D.03 Leishmaniasis prevalence (age standardized) (per 100 000 population) male
# 1.D.04 African trypanosomiasis prevalence (age standardized) (per 100 000 population) female
# 1.D.04 African trypanosomiasis prevalence (age standardized) (per 100 000 population) male
# 1.D.05 Schistosomiasis prevalence (age standardized) (per 100 000 population) female
# 1.D.05 Schistosomiasis prevalence (age standardized) (per 100 000 population) male
# 1.D.06 Cysticercosis prevalence (age standardized) (per 100 000 population) female
# 1.D.06 Cysticercosis prevalence (age standardized) (per 100 000 population) male
# 1.D.07 Cystic echinococcosis prevalence (age standardized) (per 100 000 population) female
# 1.D.07 Cystic echinococcosis prevalence (age standardized) (per 100 000 population) male
# 1.D.08 Lymphatic filariasis prevalence (age standardized) (per 100 000 population) female
# 1.D.08 Lymphatic filariasis prevalence (age standardized) (per 100 000 population) male
# 1.D.09 Onchocerciasis prevalence (age standardized) (per 100 000 population) female
# 1.D.09 Onchocerciasis prevalence (age standardized) (per 100 000 population) male
# 1.D.10 Trachoma prevalence (age standardized) (per 100 000 population) female
# 1.D.10 Trachoma prevalence (age standardized) (per 100 000 population) male
# 1.D.11 Dengue prevalence (age standardized) (per 100 000 population) female
# 1.D.11 Dengue prevalence (age standardized) (per 100 000 population) male
# 1.D.12 Yellow fever prevalence (age standardized) (per 100 000 population) female
# 1.D.12 Yellow fever prevalence (age standardized) (per 100 000 population) male
# 1.D.13 Rabies prevalence (age standardized) (per 100 000 population) female
# 1.D.13 Rabies prevalence (age standardized) (per 100 000 population) male
# 1.D.14 Intestinal nematode infections prevalence (age standardized) (per 100 000 population) female
# 1.D.14 Intestinal nematode infections prevalence (age standardized) (per 100 000 population) male
# 1.D.15 Food-borne trematodiases prevalence (age standardized) (per 100 000 population) female
# 1.D.15 Food-borne trematodiases prevalence (age standardized) (per 100 000 population) male
# 1.D.16 Other neglected tropical diseases prevalence (age standardized) (per 100 000 population) female
# 1.D.16 Other neglected tropical diseases prevalence (age standardized) (per 100 000 population) male
# 1.D.17 Leprosy prevalence (age standardized) (per 100 000 population) female
# 1.D.17 Leprosy prevalence (age standardized) (per 100 000 population) male
# 1.D.18 Ebola prevalence (age standardized) (per 100 000 population) female
# 1.D.18 Ebola prevalence (age standardized) (per 100 000 population) male
# 1.D.19 Zika virus prevalence (age standardized) (per 100 000 population) female
# 1.D.19 Zika virus prevalence (age standardized) (per 100 000 population) male
# 1.D.20 Guinea worm disease prevalence (age standardized) (per 100 000 population) female
# 1.D.20 Guinea worm disease prevalence (age standardized) (per 100 000 population) male
# 1.E.0 Other infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.E.0 Other infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.E.01 Meningitis prevalence (age standardized) (per 100 000 population) female
# 1.E.01 Meningitis prevalence (age standardized) (per 100 000 population) male
# 1.E.02 Encephalitis prevalence (age standardized) (per 100 000 population) female
# 1.E.02 Encephalitis prevalence (age standardized) (per 100 000 population) male
# 1.E.03 Diphtheria prevalence (age standardized) (per 100 000 population) female
# 1.E.03 Diphtheria prevalence (age standardized) (per 100 000 population) male
# 1.E.04 Whooping cough prevalence (age standardized) (per 100 000 population) female
# 1.E.04 Whooping cough prevalence (age standardized) (per 100 000 population) male
# 1.E.05 Tetanus prevalence (age standardized) (per 100 000 population) female
# 1.E.05 Tetanus prevalence (age standardized) (per 100 000 population) male
# 1.E.06 Measles prevalence (age standardized) (per 100 000 population) female
# 1.E.06 Measles prevalence (age standardized) (per 100 000 population) male
# 1.E.07 Varicella and herpes zoster prevalence (age standardized) (per 100 000 population) female
# 1.E.07 Varicella and herpes zoster prevalence (age standardized) (per 100 000 population) male
# 1.E.08 Acute hepatitis prevalence (age standardized) (per 100 000 population) female
# 1.E.08 Acute hepatitis prevalence (age standardized) (per 100 000 population) male
# 1.E.09 Other unspecified infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.E.09 Other unspecified infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.F.0 Maternal and neonatal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.0 Maternal and neonatal disorders prevalence (age standardized) (per 100 000 population) male
# 1.F.01 Maternal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.01 Maternal disorders prevalence (age standardized) (per 100 000 population) male
# 1.F.02 Neonatal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.02 Neonatal disorders prevalence (age standardized) (per 100 000 population) male
# 1.G.0 Nutritional deficiencies prevalence (age standardized) (per 100 000 population) female
# 1.G.0 Nutritional deficiencies prevalence (age standardized) (per 100 000 population) male
# 1.G.01 Protein-energy malnutrition prevalence (age standardized) (per 100 000 population) female
# 1.G.01 Protein-energy malnutrition prevalence (age standardized) (per 100 000 population) male
# 1.G.02 Iodine deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.02 Iodine deficiency prevalence (age standardized) (per 100 000 population) male
# 1.G.03 Vitamin A deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.03 Vitamin A deficiency prevalence (age standardized) (per 100 000 population) male
# 1.G.04 Dietary iron deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.04 Dietary iron deficiency prevalence (age standardized) (per 100 000 population) male
# 2.0.0 Non-communicable diseases prevalence (age standardized) (per 100 000 population) female
# 2.0.0 Non-communicable diseases prevalence (age standardized) (per 100 000 population) male
# 2.A.0 Neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.0 Neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.A.01 Esophageal cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.01 Esophageal cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.02 Stomach cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.02 Stomach cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.03 Liver cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.03 Liver cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.04 Larynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.04 Larynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.05 Tracheal, bronchus, and lung cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.05 Tracheal, bronchus, and lung cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.06 Breast cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.06 Breast cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.07 Cervical cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.07 Cervical cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.08 Uterine cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.08 Uterine cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.09 Prostate cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.09 Prostate cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.10 Colon and rectum cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.10 Colon and rectum cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.11 Lip and oral cavity cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.11 Lip and oral cavity cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.12 Nasopharynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.12 Nasopharynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.13 Other pharynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.13 Other pharynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.14 Gallbladder and biliary tract cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.14 Gallbladder and biliary tract cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.15 Pancreatic cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.15 Pancreatic cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.16 Malignant skin melanoma prevalence (age standardized) (per 100 000 population) female
# 2.A.16 Malignant skin melanoma prevalence (age standardized) (per 100 000 population) male
# 2.A.17 Non-melanoma skin cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.17 Non-melanoma skin cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.18 Ovarian cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.18 Ovarian cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.19 Testicular cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.19 Testicular cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.20 Kidney cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.20 Kidney cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.21 Bladder cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.21 Bladder cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.22 Brain and central nervous system cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.22 Brain and central nervous system cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.23 Thyroid cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.23 Thyroid cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.24 Mesothelioma prevalence (age standardized) (per 100 000 population) female
# 2.A.24 Mesothelioma prevalence (age standardized) (per 100 000 population) male
# 2.A.25 Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) female
# 2.A.25 Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) male
# 2.A.26 Non-Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) female
# 2.A.26 Non-Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) male
# 2.A.27 Multiple myeloma prevalence (age standardized) (per 100 000 population) female
# 2.A.27 Multiple myeloma prevalence (age standardized) (per 100 000 population) male
# 2.A.28 Leukemia prevalence (age standardized) (per 100 000 population) female
# 2.A.28 Leukemia prevalence (age standardized) (per 100 000 population) male
# 2.A.29 Other neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.29 Other neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.A.30 Other malignant neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.30 Other malignant neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.B.0 Cardiovascular diseases prevalence (age standardized) (per 100 000 population) female
# 2.B.0 Cardiovascular diseases prevalence (age standardized) (per 100 000 population) male
# 2.B.01 Rheumatic heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.01 Rheumatic heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.02 Ischemic heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.02 Ischemic heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.03 Stroke prevalence (age standardized) (per 100 000 population) female
# 2.B.03 Stroke prevalence (age standardized) (per 100 000 population) male
# 2.B.04 Hypertensive heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.04 Hypertensive heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.05 Cardiomyopathy and myocarditis prevalence (age standardized) (per 100 000 population) female
# 2.B.05 Cardiomyopathy and myocarditis prevalence (age standardized) (per 100 000 population) male
# 2.B.06 Atrial fibrillation and flutter prevalence (age standardized) (per 100 000 population) female
# 2.B.06 Atrial fibrillation and flutter prevalence (age standardized) (per 100 000 population) male
# 2.B.07 Peripheral artery disease prevalence (age standardized) (per 100 000 population) female
# 2.B.07 Peripheral artery disease prevalence (age standardized) (per 100 000 population) male
# 2.B.08 Endocarditis prevalence (age standardized) (per 100 000 population) female
# 2.B.08 Endocarditis prevalence (age standardized) (per 100 000 population) male
# 2.B.09 Non-rheumatic valvular heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.09 Non-rheumatic valvular heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.10 Other cardiovascular and circulatory diseases prevalence (age standardized) (per 100 000 population) female
# 2.B.10 Other cardiovascular and circulatory diseases prevalence (age standardized) (per 100 000 population) male
# 2.C.0 Chronic respiratory diseases prevalence (age standardized) (per 100 000 population) female
# 2.C.0 Chronic respiratory diseases prevalence (age standardized) (per 100 000 population) male
# 2.C.01 Chronic obstructive pulmonary disease prevalence (age standardized) (per 100 000 population) female
# 2.C.01 Chronic obstructive pulmonary disease prevalence (age standardized) (per 100 000 population) male
# 2.C.02 Pneumoconiosis prevalence (age standardized) (per 100 000 population) female
# 2.C.02 Pneumoconiosis prevalence (age standardized) (per 100 000 population) male
# 2.C.03 Asthma prevalence (age standardized) (per 100 000 population) female
# 2.C.03 Asthma prevalence (age standardized) (per 100 000 population) male
# 2.C.04 Interstitial lung disease and pulmonary sarcoidosis prevalence (age standardized) (per 100 000 population) female
# 2.C.04 Interstitial lung disease and pulmonary sarcoidosis prevalence (age standardized) (per 100 000 population) male
# 2.D.0 Digestive diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.0 Digestive diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.01 Cirrhosis and other chronic liver diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.01 Cirrhosis and other chronic liver diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.02 Appendicitis prevalence (age standardized) (per 100 000 population) female
# 2.D.02 Appendicitis prevalence (age standardized) (per 100 000 population) male
# 2.D.03 Paralytic ileus and intestinal obstruction prevalence (age standardized) (per 100 000 population) female
# 2.D.03 Paralytic ileus and intestinal obstruction prevalence (age standardized) (per 100 000 population) male
# 2.D.04 Inguinal, femoral, and abdominal hernia prevalence (age standardized) (per 100 000 population) female
# 2.D.04 Inguinal, femoral, and abdominal hernia prevalence (age standardized) (per 100 000 population) male
# 2.D.05 Inflammatory bowel disease prevalence (age standardized) (per 100 000 population) female
# 2.D.05 Inflammatory bowel disease prevalence (age standardized) (per 100 000 population) male
# 2.D.06 Vascular intestinal disorders prevalence (age standardized) (per 100 000 population) female
# 2.D.06 Vascular intestinal disorders prevalence (age standardized) (per 100 000 population) male
# 2.D.07 Gallbladder and biliary diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.07 Gallbladder and biliary diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.08 Pancreatitis prevalence (age standardized) (per 100 000 population) female
# 2.D.08 Pancreatitis prevalence (age standardized) (per 100 000 population) male
# 2.D.10 Upper digestive system diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.10 Upper digestive system diseases prevalence (age standardized) (per 100 000 population) male
# 2.E.0 Neurological disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.0 Neurological disorders prevalence (age standardized) (per 100 000 population) male
# 2.E.01 Alzheimer's disease and other dementias prevalence (age standardized) (per 100 000 population) female
# 2.E.01 Alzheimer's disease and other dementias prevalence (age standardized) (per 100 000 population) male
# 2.E.02 Parkinson's disease prevalence (age standardized) (per 100 000 population) female
# 2.E.02 Parkinson's disease prevalence (age standardized) (per 100 000 population) male
# 2.E.03 Idiopathic epilepsy prevalence (age standardized) (per 100 000 population) female
# 2.E.03 Idiopathic epilepsy prevalence (age standardized) (per 100 000 population) male
# 2.E.04 Multiple sclerosis prevalence (age standardized) (per 100 000 population) female
# 2.E.04 Multiple sclerosis prevalence (age standardized) (per 100 000 population) male
# 2.E.05 Motor neuron disease prevalence (age standardized) (per 100 000 population) female
# 2.E.05 Motor neuron disease prevalence (age standardized) (per 100 000 population) male
# 2.E.06 Other neurological disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.06 Other neurological disorders prevalence (age standardized) (per 100 000 population) male
# 2.E.07 Headache disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.07 Headache disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.0 Mental disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.0 Mental disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.01 Schizophrenia prevalence (age standardized) (per 100 000 population) female
# 2.F.01 Schizophrenia prevalence (age standardized) (per 100 000 population) male
# 2.F.02 Depressive disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.02 Depressive disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.03 Bipolar disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.03 Bipolar disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.04 Anxiety disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.04 Anxiety disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.05 Eating disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.05 Eating disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.06 Autism spectrum disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.06 Autism spectrum disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.07 Attention-deficit/hyperactivity disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.07 Attention-deficit/hyperactivity disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.08 Conduct disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.08 Conduct disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.09 Idiopathic developmental intellectual disability prevalence (age standardized) (per 100 000 population) female
# 2.F.09 Idiopathic developmental intellectual disability prevalence (age standardized) (per 100 000 population) male
# 2.F.10 Other mental disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.10 Other mental disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.0 Substance use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.0 Substance use disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.01 Alcohol use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.01 Alcohol use disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.02 Drug use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.02 Drug use disorders prevalence (age standardized) (per 100 000 population) male
# 2.H.0 Diabetes and kidney diseases prevalence (age standardized) (per 100 000 population) female
# 2.H.0 Diabetes and kidney diseases prevalence (age standardized) (per 100 000 population) male
# 2.H.01 Diabetes mellitus prevalence (age standardized) (per 100 000 population) female
# 2.H.01 Diabetes mellitus prevalence (age standardized) (per 100 000 population) male
# 2.H.02 Acute glomerulonephritis prevalence (age standardized) (per 100 000 population) female
# 2.H.02 Acute glomerulonephritis prevalence (age standardized) (per 100 000 population) male
# 2.H.03 Chronic kidney disease prevalence (age standardized) (per 100 000 population) female
# 2.H.03 Chronic kidney disease prevalence (age standardized) (per 100 000 population) male
# 2.I.0 Skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.0 Skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.01 Dermatitis prevalence (age standardized) (per 100 000 population) female
# 2.I.01 Dermatitis prevalence (age standardized) (per 100 000 population) male
# 2.I.02 Psoriasis prevalence (age standardized) (per 100 000 population) female
# 2.I.02 Psoriasis prevalence (age standardized) (per 100 000 population) male
# 2.I.03 Scabies prevalence (age standardized) (per 100 000 population) female
# 2.I.03 Scabies prevalence (age standardized) (per 100 000 population) male
# 2.I.04 Fungal skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.04 Fungal skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.05 Viral skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.05 Viral skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.06 Acne vulgaris prevalence (age standardized) (per 100 000 population) female
# 2.I.06 Acne vulgaris prevalence (age standardized) (per 100 000 population) male
# 2.I.07 Alopecia areata prevalence (age standardized) (per 100 000 population) female
# 2.I.07 Alopecia areata prevalence (age standardized) (per 100 000 population) male
# 2.I.08 Pruritus prevalence (age standardized) (per 100 000 population) female
# 2.I.08 Pruritus prevalence (age standardized) (per 100 000 population) male
# 2.I.09 Urticaria prevalence (age standardized) (per 100 000 population) female
# 2.I.09 Urticaria prevalence (age standardized) (per 100 000 population) male
# 2.I.10 Decubitus ulcer prevalence (age standardized) (per 100 000 population) female
# 2.I.10 Decubitus ulcer prevalence (age standardized) (per 100 000 population) male
# 2.I.11 Other skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.11 Other skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.12 Bacterial skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.12 Bacterial skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.0 Sense organ diseases prevalence (age standardized) (per 100 000 population) female
# 2.J.0 Sense organ diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.01 Age-related and other hearing loss prevalence (age standardized) (per 100 000 population) female
# 2.J.01 Age-related and other hearing loss prevalence (age standardized) (per 100 000 population) male
# 2.J.02 Other sense organ diseases prevalence (age standardized) (per 100 000 population) female
# 2.J.02 Other sense organ diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.03 Blindness and vision loss prevalence (age standardized) (per 100 000 population) female
# 2.J.03 Blindness and vision loss prevalence (age standardized) (per 100 000 population) male
# 2.K.0 Musculoskeletal disorders prevalence (age standardized) (per 100 000 population) female
# 2.K.0 Musculoskeletal disorders prevalence (age standardized) (per 100 000 population) male
# 2.K.01 Rheumatoid arthritis prevalence (age standardized) (per 100 000 population) female
# 2.K.01 Rheumatoid arthritis prevalence (age standardized) (per 100 000 population) male
# 2.K.02 Osteoarthritis prevalence (age standardized) (per 100 000 population) female
# 2.K.02 Osteoarthritis prevalence (age standardized) (per 100 000 population) male
# 2.K.03 Low back pain prevalence (age standardized) (per 100 000 population) female
# 2.K.03 Low back pain prevalence (age standardized) (per 100 000 population) male
# 2.K.04 Neck pain prevalence (age standardized) (per 100 000 population) female
# 2.K.04 Neck pain prevalence (age standardized) (per 100 000 population) male
# 2.K.05 Gout prevalence (age standardized) (per 100 000 population) female
# 2.K.05 Gout prevalence (age standardized) (per 100 000 population) male
# 2.K.06 Other musculoskeletal disorders prevalence (age standardized) (per 100 000 population) female
# 2.K.06 Other musculoskeletal disorders prevalence (age standardized) (per 100 000 population) male
# 2.L.0 Other non-communicable diseases prevalence (age standardized) (per 100 000 population) female
# 2.L.0 Other non-communicable diseases prevalence (age standardized) (per 100 000 population) male
# 2.L.01 Urinary diseases and male infertility prevalence (age standardized) (per 100 000 population) female
# 2.L.01 Urinary diseases and male infertility prevalence (age standardized) (per 100 000 population) male
# 2.L.02 Gynecological diseases prevalence (age standardized) (per 100 000 population) female
# 2.L.02 Gynecological diseases prevalence (age standardized) (per 100 000 population) male
# 2.L.03 Hemoglobinopathies and hemolytic anemias prevalence (age standardized) (per 100 000 population) female
# 2.L.03 Hemoglobinopathies and hemolytic anemias prevalence (age standardized) (per 100 000 population) male
# 2.L.04 Endocrine, metabolic, blood, and immune disorders prevalence (age standardized) (per 100 000 population) female
# 2.L.04 Endocrine, metabolic, blood, and immune disorders prevalence (age standardized) (per 100 000 population) male
# 2.L.05 Congenital birth defects prevalence (age standardized) (per 100 000 population) female
# 2.L.05 Congenital birth defects prevalence (age standardized) (per 100 000 population) male
# 2.L.06 Oral disorders prevalence (age standardized) (per 100 000 population) female
# 2.L.06 Oral disorders prevalence (age standardized) (per 100 000 population) male
# 3.0.0 Injuries prevalence (age standardized) (per 100 000 population) female
# 3.0.0 Injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.0 Transport injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.0 Transport injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.01 Road injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.01 Road injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.02 Other transport injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.02 Other transport injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.0 Unintentional injuries prevalence (age standardized) (per 100 000 population) female
# 3.B.0 Unintentional injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.01 Falls prevalence (age standardized) (per 100 000 population) female
# 3.B.01 Falls prevalence (age standardized) (per 100 000 population) male
# 3.B.02 Drowning prevalence (age standardized) (per 100 000 population) female
# 3.B.02 Drowning prevalence (age standardized) (per 100 000 population) male
# 3.B.03 Fire, heat, and hot substances prevalence (age standardized) (per 100 000 population) female
# 3.B.03 Fire, heat, and hot substances prevalence (age standardized) (per 100 000 population) male
# 3.B.04 Poisonings prevalence (age standardized) (per 100 000 population) female
# 3.B.04 Poisonings prevalence (age standardized) (per 100 000 population) male
# 3.B.05 Exposure to mechanical forces prevalence (age standardized) (per 100 000 population) female
# 3.B.05 Exposure to mechanical forces prevalence (age standardized) (per 100 000 population) male
# 3.B.06 Adverse effects of medical treatment prevalence (age standardized) (per 100 000 population) female
# 3.B.06 Adverse effects of medical treatment prevalence (age standardized) (per 100 000 population) male
# 3.B.07 Animal contact prevalence (age standardized) (per 100 000 population) female
# 3.B.07 Animal contact prevalence (age standardized) (per 100 000 population) male
# 3.B.08 Foreign body prevalence (age standardized) (per 100 000 population) female
# 3.B.08 Foreign body prevalence (age standardized) (per 100 000 population) male
# 3.B.09 Other unintentional injuries prevalence (age standardized) (per 100 000 population) female
# 3.B.09 Other unintentional injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.10 Exposure to forces of nature prevalence (age standardized) (per 100 000 population) female
# 3.B.10 Exposure to forces of nature prevalence (age standardized) (per 100 000 population) male
# 3.B.11 Environmental heat and cold exposure prevalence (age standardized) (per 100 000 population) female
# 3.B.11 Environmental heat and cold exposure prevalence (age standardized) (per 100 000 population) male
# 3.C.0 Self-harm and interpersonal violence prevalence (age standardized) (per 100 000 population) female
# 3.C.0 Self-harm and interpersonal violence prevalence (age standardized) (per 100 000 population) male
# 3.C.01 Self-harm prevalence (age standardized) (per 100 000 population) female
# 3.C.01 Self-harm prevalence (age standardized) (per 100 000 population) male
# 3.C.02 Interpersonal violence prevalence (age standardized) (per 100 000 population) female
# 3.C.02 Interpersonal violence prevalence (age standardized) (per 100 000 population) male
# 3.C.03 Executions and police conflict prevalence (age standardized) (per 100 000 population) female
# 3.C.03 Executions and police conflict prevalence (age standardized) (per 100 000 population) male
# 3.C.04 Conflict and terrorism prevalence (age standardized) (per 100 000 population) female
# 3.C.04 Conflict and terrorism prevalence (age standardized) (per 100 000 population) male
# 1.C.02 Other intestinal infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.C.02 Other intestinal infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.G.05 Other nutritional deficiencies prevalence (age standardized) (per 100 000 population) female
# 1.G.05 Other nutritional deficiencies prevalence (age standardized) (per 100 000 population) male
# 2.C.05 Other chronic respiratory diseases prevalence (age standardized) (per 100 000 population) female
# 2.C.05 Other chronic respiratory diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.09 Other digestive diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.09 Other digestive diseases prevalence (age standardized) (per 100 000 population) male
# Persistence to grade 5 (% of cohort) female
# Persistence to grade 5 (% of cohort) male
# Persistence to last grade of primary (% of cohort) female
# Persistence to last grade of primary (% of cohort) male
# Lower secondary completion rate (% of relevant age group) female
# Lower secondary completion rate (% of relevant age group) male
# Progression to secondary school (%) female
# Progression to secondary school (%) male
# Primary completion rate (% of relevant age group) female
# Primary completion rate (% of relevant age group) male
# Gross intake ratio in first grade of primary education (% of relevant age group) female
# Gross intake ratio in first grade of primary education (% of relevant age group) male
# School enrollment, primary (% net) female
# School enrollment, primary (% net) male
# Over-age students, primary (% of enrollment) female
# Over-age students, primary (% of enrollment) male
# Repeaters, primary (% of total enrollment) female
# Repeaters, primary (% of total enrollment) male
# Adjusted net enrollment rate, primary (% of primary school age children) female
# Adjusted net enrollment rate, primary (% of primary school age children) male
# Children out of school (% of primary school age) female
# Children out of school (% of primary school age) male
# School enrollment, secondary (% net) female
# School enrollment, secondary (% net) male
# Adolescents out of school (% of lower secondary school age) female
# Adolescents out of school (% of lower secondary school age) male
# Educational attainment, at least completed primary, population 25+ years (%) (cumulative) female
# Educational attainment, at least completed primary, population 25+ years (%) (cumulative) male
# Educational attainment, at least completed lower secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed lower secondary, population 25+ (%) (cumulative) male
# Educational attainment, at least completed post-secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed post-secondary, population 25+ (%) (cumulative) male
# Educational attainment, at least completed upper secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed upper secondary, population 25+ (%) (cumulative) male
# Literacy rate, youth total (% of people ages 15-24) female
# Literacy rate, youth total (% of people ages 15-24) male
# Literacy rate, adult total (% of people ages 15 and above) female
# Literacy rate, adult total (% of people ages 15 and above) male
# Employment in agriculture (% of total employment) (modeled ILO estimate) female
# Employment in agriculture (% of total employment) (modeled ILO estimate) male
# Employment to population ratio, ages 15-24 (%) (modeled ILO estimate) female
# Employment to population ratio, ages 15-24 (%) (modeled ILO estimate) male
# Employers (% of total employment) (modeled ILO estimate) female
# Employers (% of total employment) (modeled ILO estimate) male
# Self-employed, total (% of total employment) (modeled ILO estimate) female
# Self-employed, total (% of total employment) (modeled ILO estimate) male
# Employment to population ratio, 15+ (%) (modeled ILO estimate) female
# Employment to population ratio, 15+ (%) (modeled ILO estimate) male
# Vulnerable employment (% of total employment) (modeled ILO estimate) female
# Vulnerable employment (% of total employment) (modeled ILO estimate) male
# Wage and salaried workers (% of total employment) (modeled ILO estimate) female
# Wage and salaried workers (% of total employment) (modeled ILO estimate) male
# Contributing family workers (% of total employment) (modeled ILO estimate) female
# Contributing family workers (% of total employment) (modeled ILO estimate) male
# Employment in industry (% of total employment) (modeled ILO estimate) female
# Employment in industry (% of total employment) (modeled ILO estimate) male
# Labor force participation rate (% of total population ages 15-64) (modeled ILO estimate) female
# Labor force participation rate (% of total population ages 15-64) (modeled ILO estimate) male
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) female
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) male
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) female
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) male
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) female
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) male
# Unemployment (% of total labor force) (modeled ILO estimate) female
# Unemployment (% of total labor force) (modeled ILO estimate) male
# Net intake rate in grade 1 (% of official school-age population) female
# Net intake rate in grade 1 (% of official school-age population) male
# Children in employment, unpaid family workers (% of children in employment, ages 7-14) female
# Children in employment, unpaid family workers (% of children in employment, ages 7-14) male
# Children in employment (% of children ages 7-14) female
# Children in employment (% of children ages 7-14) male
# Children in employment, study and work (% of children in employment, ages 7-14) female
# Children in employment, study and work (% of children in employment, ages 7-14) male
# Children in employment, work only (% of children in employment, ages 7-14) female
# Children in employment, work only (% of children in employment, ages 7-14) male
# Children in employment, wage workers (% of children in employment, ages 7-14) female
# Children in employment, wage workers (% of children in employment, ages 7-14) male
# Educational attainment, at least Bachelor's or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, at least Bachelor's or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, Doctoral or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, Doctoral or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, at least Master's or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, at least Master's or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, at least completed short-cycle tertiary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed short-cycle tertiary, population 25+ (%) (cumulative) male
# Labor force with advanced education (% of total working-age population with advanced education) female
# Labor force with advanced education (% of total working-age population with advanced education) male
# Labor force with basic education (% of total working-age population with basic education) female
# Labor force with basic education (% of total working-age population with basic education) male
# Labor force with intermediate education (% of total working-age population with intermediate education) female
# Labor force with intermediate education (% of total working-age population with intermediate education) male
# Unemployment with advanced education (% of total labor force with advanced education) female
# Unemployment with advanced education (% of total labor force with advanced education) male
# Unemployment with basic education (% of total labor force with basic education) female
# Unemployment with basic education (% of total labor force with basic education) male
# Unemployment with intermediate education (% of total labor force with intermediate education) female
# Unemployment with intermediate education (% of total labor force with intermediate education) male
# Share of youth not in education, employment or training (% of youth population) female
# Share of youth not in education, employment or training (% of youth population) male
# Child employment in agriculture (% of economically active children ages 7-14) female
# Child employment in agriculture (% of economically active children ages 7-14) male
# Child employment in manufacturing (% of economically active children ages 7-14) female
# Child employment in manufacturing (% of economically active children ages 7-14) male
# Children in employment, self-employed (% of children in employment, ages 7-14) female
# Children in employment, self-employed (% of children in employment, ages 7-14) male
# Child employment in services (% of economically active children ages 7-14) female
# Child employment in services (% of economically active children ages 7-14) male
# Trained teachers in lower secondary education (% of total teachers) female
# Trained teachers in lower secondary education (% of total teachers) male
# Trained teachers in secondary education (% of total teachers) female
# Trained teachers in secondary education (% of total teachers) male
# Trained teachers in upper secondary education (% of total teachers) female
# Trained teachers in upper secondary education (% of total teachers) male
# Trained teachers in preprimary education (% of total teachers) female
# Trained teachers in preprimary education (% of total teachers) male
# Trained teachers in primary education (% of total teachers) female
# Trained teachers in primary education (% of total teachers) male
# Land area where elevation is below 5 meters (% of total land area) rural
# Land area where elevation is below 5 meters (% of total land area) urban
# Population living in areas where elevation is below 5 meters (% of total population) rural
# Population living in areas where elevation is below 5 meters (% of total population) urban
# Coverage of social safety net programs (% of population) Quintile 1 (poorest)
# Coverage of social safety net programs (% of population) Quintile 5 (richest)
# Coverage of social insurance programs (% of population) Quintile 1 (poorest)
# Coverage of social insurance programs (% of population) Quintile 5 (richest)
# Coverage of unemployment benefits and ALMP (% of population) Quintile 1 (poorest)
# Coverage of unemployment benefits and ALMP (% of population) Quintile 5 (richest)
# income_num

# %% [markdown]
# ### Loading Datasets

# %%
filepath_income = '../../split_income_data'
filepath_year = '../../split_year_data'

# %%
test_data_x_inc = pd.read_csv(filepath_income + '/test/X_test.csv')
test_data_x_inc = test_data_x_inc.drop(columns=['Unnamed: 0'], axis=1)
test_data_y_inc = pd.read_csv(filepath_income + '/test/y_test.csv')
test_data_y_inc = test_data_y_inc.drop(columns=['Unnamed: 0'], axis=1)

validation_inc = {}
for fold in range(0, 5):
    vdata_x = pd.read_csv(filepath_income + '/val/X_val_' + str(fold) + '.csv')
    vdata_x = vdata_x.drop(columns=['Unnamed: 0'], axis=1)
    vdata_y = pd.read_csv(filepath_income + '/val/y_val_' + str(fold) + '.csv')
    vdata_y = vdata_y.drop(columns=['Unnamed: 0'], axis=1)
    validation_inc[fold] = [vdata_x, vdata_y]

train_inc = {}
for fold in range(0, 5):
    tdata_x1 = pd.read_csv(filepath_income + '/train/X_train_' + str(fold) + '_1.csv')
    tdata_x1 = tdata_x1.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y1 = pd.read_csv(filepath_income + '/train/y_train_' + str(fold) + '_1.csv')
    tdata_y1 = tdata_y1.drop(columns=['Unnamed: 0'], axis=1)

    train_inc[fold] = [tdata_x1, tdata_y1]

# %%
test_data_x_year = pd.read_csv(filepath_year + '/test/X_test.csv')
test_data_x_year = test_data_x_year.drop(columns=['Unnamed: 0'], axis=1)
test_data_y_year = pd.read_csv(filepath_year + '/test/y_test.csv')
test_data_y_year = test_data_y_year.drop(columns=['Unnamed: 0'], axis=1)

validation_year = {}
for fold in range(0, 5):
    vdata_x = pd.read_csv(filepath_year + '/val/X_val_' + str(fold) + '.csv')
    vdata_x = vdata_x.drop(columns=['Unnamed: 0'], axis=1)
    vdata_y = pd.read_csv(filepath_year + '/val/y_val_' + str(fold) + '.csv')
    vdata_y = vdata_y.drop(columns=['Unnamed: 0'], axis=1)
    validation_year[fold] = [vdata_x, vdata_y]

train_year = {}
for fold in range(0, 5):
    tdata_x1 = pd.read_csv(filepath_year + '/train/X_train_' + str(fold) + '_1.csv')
    tdata_x1 = tdata_x1.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y1 = pd.read_csv(filepath_year + '/train/y_train_' + str(fold) + '_1.csv')
    tdata_y1 = tdata_y1.drop(columns=['Unnamed: 0'], axis=1)

    train_year[fold] = [tdata_x1, tdata_y1]

# %% [markdown]
# ### Thresholding Code

# %%
def drop_col(dataset, threshold):
    #excluding columns with greater than the threshold of NAN values 
    to_drop = []
    for col in range(0, dataset.shape[1]):
        proportion = (dataset.iloc[:,col].isnull().sum())/(dataset.shape[0])
        if proportion > threshold:
            to_drop.append(dataset.columns[col])

    colthresh = dataset.drop(to_drop, axis=1)

    colthresh = colthresh.reset_index(drop=True)

    return colthresh

def drop_row(dataset, threshold):
    
    #excluding rows with greater than the threshold of NAN values 
    to_drop = []
    for row in range(1, dataset.shape[0]):
        proportion = (dataset.iloc[row, :].isnull().sum())/(dataset.shape[1])
        if proportion > threshold:
            to_drop.append(row)
    
    rowthresh = dataset.drop(to_drop, axis=0, inplace=False)
    rowthresh = rowthresh.reset_index(drop=True)
    
    return rowthresh

# %%
def total_nan_proportion(dataset):
    total_nan = dataset.isnull().sum().sum()
    total = dataset.shape[0] * dataset.shape[1]
    proportion_total = total_nan/total 
    return proportion_total

# %%
def iterative_thresholding(dataset_to_threshold, threshold):
    last_proportion = total_nan_proportion(dataset_to_threshold)
    keep_going = True
    dataset_copy = copy.deepcopy(dataset_to_threshold.reset_index())
    changes = []

    while keep_going == True:

        dataset_copy = drop_row(dataset_copy, threshold)
        dataset_copy = drop_col(dataset_copy, threshold)
        
        
        current_proportion = total_nan_proportion(dataset_copy)
        
        #to determine whether dropping the rows and/or columns has caused other rows/columns to breach the threshold
        breached = False
        for col in range(0, dataset_copy.shape[1]):
            proportion = (dataset_copy.iloc[:,col].isnull().sum())/(dataset_copy.shape[0])
            if proportion > threshold:
                breached = True
        for row in range(1, dataset_copy.shape[0]):
            proportion = (dataset_copy.iloc[row, :].isnull().sum())/(dataset_copy.shape[1])
            if proportion > threshold:
                breached = True
        
        if breached == False:
            keep_going = False
        else: 
            changes.append(current_proportion-last_proportion)
            last_proportion = current_proportion 

    return dataset_copy, current_proportion, changes

# %% [markdown]
# ### Making Datasets

# %% [markdown]
# #### Split by Country

# %%
for t in (test_data_x_inc.columns):
    print(t)
# Out:
# date
# Women and girls who use menstrual materials (% of women and girls ages 15-49 who had a menstrual period within the last year)
# setting
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14 (% of population ages 5-14)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4 (% of population ages 0-4)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+ (% of population ages 60+)
# Women participating in own health care decisions (% of women age 15-49)
# Antiretroviral therapy coverage (% of adult males living with HIV)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+, male (% of male population ages 60+)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-24, male (2 prevent ways and reject 3 misconceptions)
# Mortality rate, infant (per 1,000 live births)
# Female genital mutilation prevalence (%)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59 (% of population ages 15-59)
# Cause of death, by injury, ages 15-59, female (% of female population ages 15-59)
# Borrowed for health or medical purposes (% age 15+)
# Prevalence of current tobacco use, females (% of female adults)
# Survival to age 65, female (% of cohort)
# Pregnant women receiving prenatal care (%)
# Mortality rate attributed to unintentional poisoning (per 100,000 population)
# Knowledge of any method of contraception (% of all women ages 15-49)
# Fertility planning status: mistimed pregnancy (% of births)
# Cause of death, by non-communicable diseases, ages 60+ (% of population ages 60+)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70 (%)
# Demand for family planning satisfied by any methods (% of married women with demand for family planning)
# Number of infant deaths, male
# Cause of death, by non-communicable diseases, ages 0-4 (% of population ages 0-4)
# Cause of death, by non-communicable diseases, ages 0-4, male (% of male population ages 0-4)
# Prevalence of underweight, weight for age (% of children under 5)
# Cause of death, by non-communicable diseases, ages 15-59, female (% of female population ages 15-59)
# Unmet need for contraception (% of married women ages 15-49)
# Mortality rate, under-5, male (per 1,000 live births)
# Knowledge of any modern method of contraception (% of all women ages 15-49)
# Prevalence of overweight, weight for height, male (% of children under 5)
# Pregnant women receiving prenatal care of at least four visits (% of pregnant women)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59, male (% of male population ages 15-59)
# Decision maker about a woman's own health care: mainly wife  (% of women age 15-49)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4, female (% of female population ages 0-4)
# Female genital mutilation prevalence (%): Q5 (highest)
# Women participating in none of the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# Cause of death, by injury, ages 5-14, male (% of male population ages 5-14)
# Incidence of HIV, ages 15-49, male (per 1,000 uninfected male population ages 15-49)
# Prevalence of severe wasting, weight for height (% of children under 5)
# Prevalence of HIV, female (% ages 15-24)
# Cause of death, by non-communicable diseases, ages 5-14, male (% of male population ages 5-14)
# Mortality caused by road traffic injury, female (per 100,000 female population)
# Suicide mortality rate, female (per 100,000 female population)
# Women's share of population ages 15+ living with HIV (%)
# Mortality caused by road traffic injury (per 100,000 population)
# Cause of death, by non-communicable diseases, male (% of male population)
# Probability of Survival to Age 5, Male
# Women and girls who participate in activities during menstrual period, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Cause of death, by injury (% of total)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-49, male (2 prevent ways and reject 3 misconceptions)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, male (% of male population)
# Cause of death, by injury, ages 5-14, female (% of female population ages 5-14)
# Knowledge of any modern method of contraception  (% of married men)
# Mortality rate, adult, male (per 1,000 male adults)
# Prevalence of underweight, weight for age, male (% of children under 5)
# Cause of death, by injury, ages 60+ (% of population ages 60+)
# Cause of death, by injury, ages 60+, female (% of female population ages 60+)
# Knowledge of any method of contraception (% of all men)
# Decision maker about a woman's own health care: wife and husband jointly (% of women age 15-49)
# Incidence of HIV, ages 15-24, male (per 1,000 uninfected male population ages 15-24)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions (% of total)
# Cause of death, by injury, ages 15-59 (% of population ages 15-59)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 60+, female (% of female population ages 60+)
# Prevalence of stunting, height for age (% of children under 5)
# Prevalence of anemia among non-pregnant women (% of women ages 15-49)
# Women and girls who use menstrual materials, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Incidence of HIV, ages 15-49 (per 1,000 uninfected population ages 15-49)
# Women and girls who participate in activities during menstrual period (% of women and girls ages 15-49 who had a menstrual period within the last year)
# Fraction of Children Under 5 Not Stunted, Male
# Survival to age 65, male (% of cohort)
# Condom use at last high-risk sex, adult female (% ages 15-49)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-24, female (2 prevent ways and reject 3 misconceptions)
# Borrowed for health or medical purposes, female (% age 15+)
# Borrowed for health or medical purposes, male (% age 15+)
# Prevalence of overweight, female (% of female adults)
# Knowledge of any modern method of contraception (% of married women ages 15-49)
# Cause of death, by non-communicable diseases, ages 5-14, female (% of female population ages 5-14)
# Female genital mutilation prevalence (%): Q1 (lowest)
# Cause of death, by non-communicable diseases, ages 15-59 (% of population ages 15-59)
# Cause of death, by non-communicable diseases, ages 5-14 (% of population ages 5-14)
# Cause of death, by non-communicable diseases, female (% of female population)
# Cause of death, by injury, female (% of female population)
# Mortality rate, infant, female (per 1,000 live births)
# Cause of death, by injury, ages 5-14 (% of population ages 5-14)
# Knowledge of any modern method of contraception  (% of all men)
# Contraceptive prevalence, any modern method (% of married women ages 15-49)
# Prevalence of stunting, height for age, female (% of children under 5)
# Prevalence of syphilis (% of women attending antenatal care)
# Prevalence of current tobacco use (% of adults)
# Women and girls who participate in activities during menstrual period, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Adolescent fertility rate (births per 1,000 women ages 15-19)
# Prevalence of wasting, weight for height (% of children under 5)
# Knowledge of any method of contraception (% of married men)
# Women making their own informed decisions regarding sexual relations, contraceptive use and reproductive health care  (% of women age 15-49)
# People practicing open defecation, rural (% of rural population)
# Number of under-five deaths, male
# Probability of Survival to Age 5, Female
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 15-59, female (% of female population ages 15-59)
# Women and girls who have private places to wash and change during menstrual period, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Number of infant deaths, female
# Births attended by skilled health staff (% of total)
# Prevalence of overweight (% of adults)
# Suicide mortality rate, male (per 100,000 male population)
# Condom use at last high-risk sex, adult male (% ages 15-49)
# Total alcohol consumption per capita (liters of pure alcohol, projected estimates, 15+ years of age)
# Mortality rate, under-5, female (per 1,000 live births)
# Intermittent preventive treatment (IPT) of malaria in pregnancy (% of pregnant women)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14, male (% of male population ages 5-14)
# Prevalence of overweight, male (% of male adults)
# Fraction of Children Under 5 Not Stunted
# Survival Rate from Age 15-60, Female
# Women and girls who use menstrual materials, urban (% of women and girls ages 15-49 living in urban areas who had a menstrual period within the last year)
# Prevalence of overweight, weight for height (% of children under 5)
# Stillbirth rate (per 1,000 total births)
# Women and girls who have private places to wash and change during menstrual period (% of women and girls ages 15-49 who had a menstrual period within the last year)
# Cause of death, by non-communicable diseases, ages 15-59, male (% of male population ages 15-59)
# Female genital mutilation prevalence (%): Q2
# Wanted fertility rate (births per woman)
# Fertility planning status: unwanted pregnancy (% of births)
# Mortality rate, infant, male (per 1,000 live births)
# Prevalence of anemia among women of reproductive age (% of women ages 15-49)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, female (% of female population)
# Total alcohol consumption per capita, male (liters of pure alcohol, projected estimates, male 15+ years of age)
# Mortality rate attributed to unintentional poisoning, male (per 100,000 male population)
# Cause of death, by non-communicable diseases (% of total)
# Decision maker about a woman's own health care: other (% of women age 15-49)
# Immunization, DPT (% of children ages 12-23 months)
# Incidence of HIV, ages 15-24, female (per 1,000 uninfected female population ages 15-24)
# Women participating in the three decisions (own health care, major household purchases, and visiting family) (% of women age 15-49)
# People practicing open defecation, urban (% of urban population)
# Cause of death, by non-communicable diseases, ages 60+, female (% of female population ages 60+)
# Prevalence of wasting, weight for height, male (% of children under 5)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, female (%)
# Cause of death, by injury, male (% of male population)
# Mortality rate, adult, female (per 1,000 female adults)
# Cause of death, by injury, ages 0-4, male (% of male population ages 0-4)
# Fertility rate, total (births per woman)
# Mortality rate attributed to unintentional poisoning, female (per 100,000 female population)
# Decision maker about a woman's own health care: mainly husband (% of women age 15-49)
# Number of stillbirths
# Suicide mortality rate (per 100,000 population)
# Survival Rate from Age 15-60
# Knowledge of any method of contraception (% of married women ages 15-49)
# Prevalence of stunting, height for age, male (% of children under 5)
# Incidence of HIV, ages 15-24 (per 1,000 uninfected population ages 15-24)
# People practicing open defecation (% of population)
# Female genital mutilation prevalence (%): Q3
# Probability of Survival to Age 5
# Prevalence of obesity, female (% of female population ages 18+)
# Prevalence of severe wasting, weight for height, male (% of children under 5)
# Total alcohol consumption per capita, female (liters of pure alcohol, projected estimates, female 15+ years of age)
# Cause of death, by injury, ages 0-4 (% of population ages 0-4)
# Number of infant deaths
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 5-14, female (% of female population ages 5-14)
# Prevalence of severe wasting, weight for height, female (% of children under 5)
# Fertility planning status: planned pregnancy (% of births)
# Antiretroviral therapy coverage (% of adult females living with HIV)
# Cause of death, by injury, ages 15-59, male (% of male population ages 15-59)
# Prevalence of obesity, male (% of male population ages 18+)
# Demand for family planning satisfied by modern methods (% of married women with demand for family planning)
# Prevalence of HIV, male (% ages 15-24)
# Survival Rate from Age 15-60, Male
# Mortality caused by road traffic injury, male (per 100,000 male population)
# Prevalence of underweight, weight for age, female (% of children under 5)
# Immunization, measles (% of children ages 12-23 months)
# Contraceptive prevalence, any method (% of married women ages 15-49)
# Number of under-five deaths, female
# Prevalence of wasting, weight for height, female (% of children under 5)
# Antiretroviral therapy coverage for PMTCT (% of pregnant women living with HIV)
# Prevalence of anemia among pregnant women (%)
# Cause of death, by injury, ages 0-4, female (% of female population ages 0-4)
# Mortality rate, under-5 (per 1,000 live births)
# Comprehensive correct knowledge of HIV/AIDS, ages 15-49, female (2 prevent ways and reject 3 misconceptions)
# Cause of death, by communicable diseases and maternal, prenatal and nutrition conditions, ages 0-4, male (% of male population ages 0-4)
# Mortality from CVD, cancer, diabetes or CRD between exact ages 30 and 70, male (%)
# Decision maker about a woman's own health care: someone else (% of women age 15-49)
# Prevalence of overweight, weight for height, female (% of children under 5)
# Cause of death, by injury, ages 60+, male (% of male population ages 60+)
# Cause of death, by non-communicable diseases, ages 60+, male (% of male population ages 60+)
# Cause of death, by non-communicable diseases, ages 0-4, female (% of female population ages 0-4)
# Female genital mutilation prevalence (%): Q4
# Incidence of HIV, ages 15-49, female (per 1,000 uninfected female population ages 15-49)
# Fraction of Children Under 5 Not Stunted, Female
# Prevalence of current tobacco use, males (% of male adults)
# Women and girls who have private places to wash and change during menstrual period, rural (% of women and girls ages 15-49 living in rural areas who had a menstrual period within the last year)
# Teenage mothers (% of women ages 15-19 who have had children or are currently pregnant)
# Women with high empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with high empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with low empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with low empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with medium empowerment in the attitude to violence domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the attitude to violence domain (%) Quintile 5 (richest)
# Women with high empowerment in the decision-making domain (%) Quintile 1 (poorest)
# Women with high empowerment in the decision-making domain (%) Quintile 5 (richest)
# Women with low empowerment in the decision-making  domain (%) Quintile 1 (poorest)
# Women with low empowerment in the decision-making  domain (%) Quintile 5 (richest)
# Women with medium empowerment in the decision-making domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the decision-making domain (%) Quintile 5 (richest)
# Women with high empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with high empowerment in the social independence domain (%) Quintile 5 (richest)
# Women with low empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with low empowerment in the social independence domain (%) Quintile 5 (richest)
# Women with medium empowerment in the social independence domain (%) Quintile 1 (poorest)
# Women with medium empowerment in the social independence domain (%) Quintile 5 (richest)
# 0.0.0 All causes prevalence (age standardized) (per 100 000 population) female
# 0.0.0 All causes prevalence (age standardized) (per 100 000 population) male
# 1.0.0 Communicable, maternal, neonatal, and nutritional diseases prevalence (age standardized) (per 100 000 population) female
# 1.0.0 Communicable, maternal, neonatal, and nutritional diseases prevalence (age standardized) (per 100 000 population) male
# 1.A.0 HIV/AIDS and sexually transmitted infections prevalence (age standardized) (per 100 000 population) female
# 1.A.0 HIV/AIDS and sexually transmitted infections prevalence (age standardized) (per 100 000 population) male
# 1.A.01 HIV/AIDS prevalence (age standardized) (per 100 000 population) female
# 1.A.01 HIV/AIDS prevalence (age standardized) (per 100 000 population) male
# 1.A.02 Sexually transmitted infections excluding HIV prevalence (age standardized) (per 100 000 population) female
# 1.A.02 Sexually transmitted infections excluding HIV prevalence (age standardized) (per 100 000 population) male
# 1.B.0 Respiratory infections and tuberculosis prevalence (age standardized) (per 100 000 population) female
# 1.B.0 Respiratory infections and tuberculosis prevalence (age standardized) (per 100 000 population) male
# 1.B.01 Tuberculosis prevalence (age standardized) (per 100 000 population) female
# 1.B.01 Tuberculosis prevalence (age standardized) (per 100 000 population) male
# 1.B.02 Lower respiratory infections prevalence (age standardized) (per 100 000 population) female
# 1.B.02 Lower respiratory infections prevalence (age standardized) (per 100 000 population) male
# 1.B.03 Upper respiratory infections prevalence (age standardized) (per 100 000 population) female
# 1.B.03 Upper respiratory infections prevalence (age standardized) (per 100 000 population) male
# 1.B.04 Otitis media prevalence (age standardized) (per 100 000 population) female
# 1.B.04 Otitis media prevalence (age standardized) (per 100 000 population) male
# 1.C.0 Enteric infections prevalence (age standardized) (per 100 000 population) female
# 1.C.0 Enteric infections prevalence (age standardized) (per 100 000 population) male
# 1.C.01 Diarrheal diseases prevalence (age standardized) (per 100 000 population) female
# 1.C.01 Diarrheal diseases prevalence (age standardized) (per 100 000 population) male
# 1.C.03 Typhoid and paratyphoid prevalence (age standardized) (per 100 000 population) female
# 1.C.03 Typhoid and paratyphoid prevalence (age standardized) (per 100 000 population) male
# 1.C.04 Invasive Non-typhoidal Salmonella (iNTS) prevalence (age standardized) (per 100 000 population) female
# 1.C.04 Invasive Non-typhoidal Salmonella (iNTS) prevalence (age standardized) (per 100 000 population) male
# 1.D.0 Neglected tropical diseases and malaria prevalence (age standardized) (per 100 000 population) female
# 1.D.0 Neglected tropical diseases and malaria prevalence (age standardized) (per 100 000 population) male
# 1.D.01 Malaria prevalence (age standardized) (per 100 000 population) female
# 1.D.01 Malaria prevalence (age standardized) (per 100 000 population) male
# 1.D.02 Chagas disease prevalence (age standardized) (per 100 000 population) female
# 1.D.02 Chagas disease prevalence (age standardized) (per 100 000 population) male
# 1.D.03 Leishmaniasis prevalence (age standardized) (per 100 000 population) female
# 1.D.03 Leishmaniasis prevalence (age standardized) (per 100 000 population) male
# 1.D.04 African trypanosomiasis prevalence (age standardized) (per 100 000 population) female
# 1.D.04 African trypanosomiasis prevalence (age standardized) (per 100 000 population) male
# 1.D.05 Schistosomiasis prevalence (age standardized) (per 100 000 population) female
# 1.D.05 Schistosomiasis prevalence (age standardized) (per 100 000 population) male
# 1.D.06 Cysticercosis prevalence (age standardized) (per 100 000 population) female
# 1.D.06 Cysticercosis prevalence (age standardized) (per 100 000 population) male
# 1.D.07 Cystic echinococcosis prevalence (age standardized) (per 100 000 population) female
# 1.D.07 Cystic echinococcosis prevalence (age standardized) (per 100 000 population) male
# 1.D.08 Lymphatic filariasis prevalence (age standardized) (per 100 000 population) female
# 1.D.08 Lymphatic filariasis prevalence (age standardized) (per 100 000 population) male
# 1.D.09 Onchocerciasis prevalence (age standardized) (per 100 000 population) female
# 1.D.09 Onchocerciasis prevalence (age standardized) (per 100 000 population) male
# 1.D.10 Trachoma prevalence (age standardized) (per 100 000 population) female
# 1.D.10 Trachoma prevalence (age standardized) (per 100 000 population) male
# 1.D.11 Dengue prevalence (age standardized) (per 100 000 population) female
# 1.D.11 Dengue prevalence (age standardized) (per 100 000 population) male
# 1.D.12 Yellow fever prevalence (age standardized) (per 100 000 population) female
# 1.D.12 Yellow fever prevalence (age standardized) (per 100 000 population) male
# 1.D.13 Rabies prevalence (age standardized) (per 100 000 population) female
# 1.D.13 Rabies prevalence (age standardized) (per 100 000 population) male
# 1.D.14 Intestinal nematode infections prevalence (age standardized) (per 100 000 population) female
# 1.D.14 Intestinal nematode infections prevalence (age standardized) (per 100 000 population) male
# 1.D.15 Food-borne trematodiases prevalence (age standardized) (per 100 000 population) female
# 1.D.15 Food-borne trematodiases prevalence (age standardized) (per 100 000 population) male
# 1.D.16 Other neglected tropical diseases prevalence (age standardized) (per 100 000 population) female
# 1.D.16 Other neglected tropical diseases prevalence (age standardized) (per 100 000 population) male
# 1.D.17 Leprosy prevalence (age standardized) (per 100 000 population) female
# 1.D.17 Leprosy prevalence (age standardized) (per 100 000 population) male
# 1.D.18 Ebola prevalence (age standardized) (per 100 000 population) female
# 1.D.18 Ebola prevalence (age standardized) (per 100 000 population) male
# 1.D.19 Zika virus prevalence (age standardized) (per 100 000 population) female
# 1.D.19 Zika virus prevalence (age standardized) (per 100 000 population) male
# 1.D.20 Guinea worm disease prevalence (age standardized) (per 100 000 population) female
# 1.D.20 Guinea worm disease prevalence (age standardized) (per 100 000 population) male
# 1.E.0 Other infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.E.0 Other infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.E.01 Meningitis prevalence (age standardized) (per 100 000 population) female
# 1.E.01 Meningitis prevalence (age standardized) (per 100 000 population) male
# 1.E.02 Encephalitis prevalence (age standardized) (per 100 000 population) female
# 1.E.02 Encephalitis prevalence (age standardized) (per 100 000 population) male
# 1.E.03 Diphtheria prevalence (age standardized) (per 100 000 population) female
# 1.E.03 Diphtheria prevalence (age standardized) (per 100 000 population) male
# 1.E.04 Whooping cough prevalence (age standardized) (per 100 000 population) female
# 1.E.04 Whooping cough prevalence (age standardized) (per 100 000 population) male
# 1.E.05 Tetanus prevalence (age standardized) (per 100 000 population) female
# 1.E.05 Tetanus prevalence (age standardized) (per 100 000 population) male
# 1.E.06 Measles prevalence (age standardized) (per 100 000 population) female
# 1.E.06 Measles prevalence (age standardized) (per 100 000 population) male
# 1.E.07 Varicella and herpes zoster prevalence (age standardized) (per 100 000 population) female
# 1.E.07 Varicella and herpes zoster prevalence (age standardized) (per 100 000 population) male
# 1.E.08 Acute hepatitis prevalence (age standardized) (per 100 000 population) female
# 1.E.08 Acute hepatitis prevalence (age standardized) (per 100 000 population) male
# 1.E.09 Other unspecified infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.E.09 Other unspecified infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.F.0 Maternal and neonatal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.0 Maternal and neonatal disorders prevalence (age standardized) (per 100 000 population) male
# 1.F.01 Maternal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.01 Maternal disorders prevalence (age standardized) (per 100 000 population) male
# 1.F.02 Neonatal disorders prevalence (age standardized) (per 100 000 population) female
# 1.F.02 Neonatal disorders prevalence (age standardized) (per 100 000 population) male
# 1.G.0 Nutritional deficiencies prevalence (age standardized) (per 100 000 population) female
# 1.G.0 Nutritional deficiencies prevalence (age standardized) (per 100 000 population) male
# 1.G.01 Protein-energy malnutrition prevalence (age standardized) (per 100 000 population) female
# 1.G.01 Protein-energy malnutrition prevalence (age standardized) (per 100 000 population) male
# 1.G.02 Iodine deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.02 Iodine deficiency prevalence (age standardized) (per 100 000 population) male
# 1.G.03 Vitamin A deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.03 Vitamin A deficiency prevalence (age standardized) (per 100 000 population) male
# 1.G.04 Dietary iron deficiency prevalence (age standardized) (per 100 000 population) female
# 1.G.04 Dietary iron deficiency prevalence (age standardized) (per 100 000 population) male
# 2.0.0 Non-communicable diseases prevalence (age standardized) (per 100 000 population) female
# 2.0.0 Non-communicable diseases prevalence (age standardized) (per 100 000 population) male
# 2.A.0 Neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.0 Neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.A.01 Esophageal cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.01 Esophageal cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.02 Stomach cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.02 Stomach cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.03 Liver cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.03 Liver cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.04 Larynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.04 Larynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.05 Tracheal, bronchus, and lung cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.05 Tracheal, bronchus, and lung cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.06 Breast cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.06 Breast cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.07 Cervical cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.07 Cervical cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.08 Uterine cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.08 Uterine cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.09 Prostate cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.09 Prostate cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.10 Colon and rectum cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.10 Colon and rectum cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.11 Lip and oral cavity cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.11 Lip and oral cavity cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.12 Nasopharynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.12 Nasopharynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.13 Other pharynx cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.13 Other pharynx cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.14 Gallbladder and biliary tract cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.14 Gallbladder and biliary tract cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.15 Pancreatic cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.15 Pancreatic cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.16 Malignant skin melanoma prevalence (age standardized) (per 100 000 population) female
# 2.A.16 Malignant skin melanoma prevalence (age standardized) (per 100 000 population) male
# 2.A.17 Non-melanoma skin cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.17 Non-melanoma skin cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.18 Ovarian cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.18 Ovarian cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.19 Testicular cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.19 Testicular cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.20 Kidney cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.20 Kidney cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.21 Bladder cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.21 Bladder cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.22 Brain and central nervous system cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.22 Brain and central nervous system cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.23 Thyroid cancer prevalence (age standardized) (per 100 000 population) female
# 2.A.23 Thyroid cancer prevalence (age standardized) (per 100 000 population) male
# 2.A.24 Mesothelioma prevalence (age standardized) (per 100 000 population) female
# 2.A.24 Mesothelioma prevalence (age standardized) (per 100 000 population) male
# 2.A.25 Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) female
# 2.A.25 Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) male
# 2.A.26 Non-Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) female
# 2.A.26 Non-Hodgkin lymphoma prevalence (age standardized) (per 100 000 population) male
# 2.A.27 Multiple myeloma prevalence (age standardized) (per 100 000 population) female
# 2.A.27 Multiple myeloma prevalence (age standardized) (per 100 000 population) male
# 2.A.28 Leukemia prevalence (age standardized) (per 100 000 population) female
# 2.A.28 Leukemia prevalence (age standardized) (per 100 000 population) male
# 2.A.29 Other neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.29 Other neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.A.30 Other malignant neoplasms prevalence (age standardized) (per 100 000 population) female
# 2.A.30 Other malignant neoplasms prevalence (age standardized) (per 100 000 population) male
# 2.B.0 Cardiovascular diseases prevalence (age standardized) (per 100 000 population) female
# 2.B.0 Cardiovascular diseases prevalence (age standardized) (per 100 000 population) male
# 2.B.01 Rheumatic heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.01 Rheumatic heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.02 Ischemic heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.02 Ischemic heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.03 Stroke prevalence (age standardized) (per 100 000 population) female
# 2.B.03 Stroke prevalence (age standardized) (per 100 000 population) male
# 2.B.04 Hypertensive heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.04 Hypertensive heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.05 Cardiomyopathy and myocarditis prevalence (age standardized) (per 100 000 population) female
# 2.B.05 Cardiomyopathy and myocarditis prevalence (age standardized) (per 100 000 population) male
# 2.B.06 Atrial fibrillation and flutter prevalence (age standardized) (per 100 000 population) female
# 2.B.06 Atrial fibrillation and flutter prevalence (age standardized) (per 100 000 population) male
# 2.B.07 Peripheral artery disease prevalence (age standardized) (per 100 000 population) female
# 2.B.07 Peripheral artery disease prevalence (age standardized) (per 100 000 population) male
# 2.B.08 Endocarditis prevalence (age standardized) (per 100 000 population) female
# 2.B.08 Endocarditis prevalence (age standardized) (per 100 000 population) male
# 2.B.09 Non-rheumatic valvular heart disease prevalence (age standardized) (per 100 000 population) female
# 2.B.09 Non-rheumatic valvular heart disease prevalence (age standardized) (per 100 000 population) male
# 2.B.10 Other cardiovascular and circulatory diseases prevalence (age standardized) (per 100 000 population) female
# 2.B.10 Other cardiovascular and circulatory diseases prevalence (age standardized) (per 100 000 population) male
# 2.C.0 Chronic respiratory diseases prevalence (age standardized) (per 100 000 population) female
# 2.C.0 Chronic respiratory diseases prevalence (age standardized) (per 100 000 population) male
# 2.C.01 Chronic obstructive pulmonary disease prevalence (age standardized) (per 100 000 population) female
# 2.C.01 Chronic obstructive pulmonary disease prevalence (age standardized) (per 100 000 population) male
# 2.C.02 Pneumoconiosis prevalence (age standardized) (per 100 000 population) female
# 2.C.02 Pneumoconiosis prevalence (age standardized) (per 100 000 population) male
# 2.C.03 Asthma prevalence (age standardized) (per 100 000 population) female
# 2.C.03 Asthma prevalence (age standardized) (per 100 000 population) male
# 2.C.04 Interstitial lung disease and pulmonary sarcoidosis prevalence (age standardized) (per 100 000 population) female
# 2.C.04 Interstitial lung disease and pulmonary sarcoidosis prevalence (age standardized) (per 100 000 population) male
# 2.D.0 Digestive diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.0 Digestive diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.01 Cirrhosis and other chronic liver diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.01 Cirrhosis and other chronic liver diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.02 Appendicitis prevalence (age standardized) (per 100 000 population) female
# 2.D.02 Appendicitis prevalence (age standardized) (per 100 000 population) male
# 2.D.03 Paralytic ileus and intestinal obstruction prevalence (age standardized) (per 100 000 population) female
# 2.D.03 Paralytic ileus and intestinal obstruction prevalence (age standardized) (per 100 000 population) male
# 2.D.04 Inguinal, femoral, and abdominal hernia prevalence (age standardized) (per 100 000 population) female
# 2.D.04 Inguinal, femoral, and abdominal hernia prevalence (age standardized) (per 100 000 population) male
# 2.D.05 Inflammatory bowel disease prevalence (age standardized) (per 100 000 population) female
# 2.D.05 Inflammatory bowel disease prevalence (age standardized) (per 100 000 population) male
# 2.D.06 Vascular intestinal disorders prevalence (age standardized) (per 100 000 population) female
# 2.D.06 Vascular intestinal disorders prevalence (age standardized) (per 100 000 population) male
# 2.D.07 Gallbladder and biliary diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.07 Gallbladder and biliary diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.08 Pancreatitis prevalence (age standardized) (per 100 000 population) female
# 2.D.08 Pancreatitis prevalence (age standardized) (per 100 000 population) male
# 2.D.10 Upper digestive system diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.10 Upper digestive system diseases prevalence (age standardized) (per 100 000 population) male
# 2.E.0 Neurological disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.0 Neurological disorders prevalence (age standardized) (per 100 000 population) male
# 2.E.01 Alzheimer's disease and other dementias prevalence (age standardized) (per 100 000 population) female
# 2.E.01 Alzheimer's disease and other dementias prevalence (age standardized) (per 100 000 population) male
# 2.E.02 Parkinson's disease prevalence (age standardized) (per 100 000 population) female
# 2.E.02 Parkinson's disease prevalence (age standardized) (per 100 000 population) male
# 2.E.03 Idiopathic epilepsy prevalence (age standardized) (per 100 000 population) female
# 2.E.03 Idiopathic epilepsy prevalence (age standardized) (per 100 000 population) male
# 2.E.04 Multiple sclerosis prevalence (age standardized) (per 100 000 population) female
# 2.E.04 Multiple sclerosis prevalence (age standardized) (per 100 000 population) male
# 2.E.05 Motor neuron disease prevalence (age standardized) (per 100 000 population) female
# 2.E.05 Motor neuron disease prevalence (age standardized) (per 100 000 population) male
# 2.E.06 Other neurological disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.06 Other neurological disorders prevalence (age standardized) (per 100 000 population) male
# 2.E.07 Headache disorders prevalence (age standardized) (per 100 000 population) female
# 2.E.07 Headache disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.0 Mental disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.0 Mental disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.01 Schizophrenia prevalence (age standardized) (per 100 000 population) female
# 2.F.01 Schizophrenia prevalence (age standardized) (per 100 000 population) male
# 2.F.02 Depressive disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.02 Depressive disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.03 Bipolar disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.03 Bipolar disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.04 Anxiety disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.04 Anxiety disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.05 Eating disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.05 Eating disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.06 Autism spectrum disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.06 Autism spectrum disorders prevalence (age standardized) (per 100 000 population) male
# 2.F.07 Attention-deficit/hyperactivity disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.07 Attention-deficit/hyperactivity disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.08 Conduct disorder prevalence (age standardized) (per 100 000 population) female
# 2.F.08 Conduct disorder prevalence (age standardized) (per 100 000 population) male
# 2.F.09 Idiopathic developmental intellectual disability prevalence (age standardized) (per 100 000 population) female
# 2.F.09 Idiopathic developmental intellectual disability prevalence (age standardized) (per 100 000 population) male
# 2.F.10 Other mental disorders prevalence (age standardized) (per 100 000 population) female
# 2.F.10 Other mental disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.0 Substance use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.0 Substance use disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.01 Alcohol use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.01 Alcohol use disorders prevalence (age standardized) (per 100 000 population) male
# 2.G.02 Drug use disorders prevalence (age standardized) (per 100 000 population) female
# 2.G.02 Drug use disorders prevalence (age standardized) (per 100 000 population) male
# 2.H.0 Diabetes and kidney diseases prevalence (age standardized) (per 100 000 population) female
# 2.H.0 Diabetes and kidney diseases prevalence (age standardized) (per 100 000 population) male
# 2.H.01 Diabetes mellitus prevalence (age standardized) (per 100 000 population) female
# 2.H.01 Diabetes mellitus prevalence (age standardized) (per 100 000 population) male
# 2.H.02 Acute glomerulonephritis prevalence (age standardized) (per 100 000 population) female
# 2.H.02 Acute glomerulonephritis prevalence (age standardized) (per 100 000 population) male
# 2.H.03 Chronic kidney disease prevalence (age standardized) (per 100 000 population) female
# 2.H.03 Chronic kidney disease prevalence (age standardized) (per 100 000 population) male
# 2.I.0 Skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.0 Skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.01 Dermatitis prevalence (age standardized) (per 100 000 population) female
# 2.I.01 Dermatitis prevalence (age standardized) (per 100 000 population) male
# 2.I.02 Psoriasis prevalence (age standardized) (per 100 000 population) female
# 2.I.02 Psoriasis prevalence (age standardized) (per 100 000 population) male
# 2.I.03 Scabies prevalence (age standardized) (per 100 000 population) female
# 2.I.03 Scabies prevalence (age standardized) (per 100 000 population) male
# 2.I.04 Fungal skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.04 Fungal skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.05 Viral skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.05 Viral skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.06 Acne vulgaris prevalence (age standardized) (per 100 000 population) female
# 2.I.06 Acne vulgaris prevalence (age standardized) (per 100 000 population) male
# 2.I.07 Alopecia areata prevalence (age standardized) (per 100 000 population) female
# 2.I.07 Alopecia areata prevalence (age standardized) (per 100 000 population) male
# 2.I.08 Pruritus prevalence (age standardized) (per 100 000 population) female
# 2.I.08 Pruritus prevalence (age standardized) (per 100 000 population) male
# 2.I.09 Urticaria prevalence (age standardized) (per 100 000 population) female
# 2.I.09 Urticaria prevalence (age standardized) (per 100 000 population) male
# 2.I.10 Decubitus ulcer prevalence (age standardized) (per 100 000 population) female
# 2.I.10 Decubitus ulcer prevalence (age standardized) (per 100 000 population) male
# 2.I.11 Other skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.11 Other skin and subcutaneous diseases prevalence (age standardized) (per 100 000 population) male
# 2.I.12 Bacterial skin diseases prevalence (age standardized) (per 100 000 population) female
# 2.I.12 Bacterial skin diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.0 Sense organ diseases prevalence (age standardized) (per 100 000 population) female
# 2.J.0 Sense organ diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.01 Age-related and other hearing loss prevalence (age standardized) (per 100 000 population) female
# 2.J.01 Age-related and other hearing loss prevalence (age standardized) (per 100 000 population) male
# 2.J.02 Other sense organ diseases prevalence (age standardized) (per 100 000 population) female
# 2.J.02 Other sense organ diseases prevalence (age standardized) (per 100 000 population) male
# 2.J.03 Blindness and vision loss prevalence (age standardized) (per 100 000 population) female
# 2.J.03 Blindness and vision loss prevalence (age standardized) (per 100 000 population) male
# 2.K.0 Musculoskeletal disorders prevalence (age standardized) (per 100 000 population) female
# 2.K.0 Musculoskeletal disorders prevalence (age standardized) (per 100 000 population) male
# 2.K.01 Rheumatoid arthritis prevalence (age standardized) (per 100 000 population) female
# 2.K.01 Rheumatoid arthritis prevalence (age standardized) (per 100 000 population) male
# 2.K.02 Osteoarthritis prevalence (age standardized) (per 100 000 population) female
# 2.K.02 Osteoarthritis prevalence (age standardized) (per 100 000 population) male
# 2.K.03 Low back pain prevalence (age standardized) (per 100 000 population) female
# 2.K.03 Low back pain prevalence (age standardized) (per 100 000 population) male
# 2.K.04 Neck pain prevalence (age standardized) (per 100 000 population) female
# 2.K.04 Neck pain prevalence (age standardized) (per 100 000 population) male
# 2.K.05 Gout prevalence (age standardized) (per 100 000 population) female
# 2.K.05 Gout prevalence (age standardized) (per 100 000 population) male
# 2.K.06 Other musculoskeletal disorders prevalence (age standardized) (per 100 000 population) female
# 2.K.06 Other musculoskeletal disorders prevalence (age standardized) (per 100 000 population) male
# 2.L.0 Other non-communicable diseases prevalence (age standardized) (per 100 000 population) female
# 2.L.0 Other non-communicable diseases prevalence (age standardized) (per 100 000 population) male
# 2.L.01 Urinary diseases and male infertility prevalence (age standardized) (per 100 000 population) female
# 2.L.01 Urinary diseases and male infertility prevalence (age standardized) (per 100 000 population) male
# 2.L.02 Gynecological diseases prevalence (age standardized) (per 100 000 population) female
# 2.L.02 Gynecological diseases prevalence (age standardized) (per 100 000 population) male
# 2.L.03 Hemoglobinopathies and hemolytic anemias prevalence (age standardized) (per 100 000 population) female
# 2.L.03 Hemoglobinopathies and hemolytic anemias prevalence (age standardized) (per 100 000 population) male
# 2.L.04 Endocrine, metabolic, blood, and immune disorders prevalence (age standardized) (per 100 000 population) female
# 2.L.04 Endocrine, metabolic, blood, and immune disorders prevalence (age standardized) (per 100 000 population) male
# 2.L.05 Congenital birth defects prevalence (age standardized) (per 100 000 population) female
# 2.L.05 Congenital birth defects prevalence (age standardized) (per 100 000 population) male
# 2.L.06 Oral disorders prevalence (age standardized) (per 100 000 population) female
# 2.L.06 Oral disorders prevalence (age standardized) (per 100 000 population) male
# 3.0.0 Injuries prevalence (age standardized) (per 100 000 population) female
# 3.0.0 Injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.0 Transport injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.0 Transport injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.01 Road injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.01 Road injuries prevalence (age standardized) (per 100 000 population) male
# 3.A.02 Other transport injuries prevalence (age standardized) (per 100 000 population) female
# 3.A.02 Other transport injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.0 Unintentional injuries prevalence (age standardized) (per 100 000 population) female
# 3.B.0 Unintentional injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.01 Falls prevalence (age standardized) (per 100 000 population) female
# 3.B.01 Falls prevalence (age standardized) (per 100 000 population) male
# 3.B.02 Drowning prevalence (age standardized) (per 100 000 population) female
# 3.B.02 Drowning prevalence (age standardized) (per 100 000 population) male
# 3.B.03 Fire, heat, and hot substances prevalence (age standardized) (per 100 000 population) female
# 3.B.03 Fire, heat, and hot substances prevalence (age standardized) (per 100 000 population) male
# 3.B.04 Poisonings prevalence (age standardized) (per 100 000 population) female
# 3.B.04 Poisonings prevalence (age standardized) (per 100 000 population) male
# 3.B.05 Exposure to mechanical forces prevalence (age standardized) (per 100 000 population) female
# 3.B.05 Exposure to mechanical forces prevalence (age standardized) (per 100 000 population) male
# 3.B.06 Adverse effects of medical treatment prevalence (age standardized) (per 100 000 population) female
# 3.B.06 Adverse effects of medical treatment prevalence (age standardized) (per 100 000 population) male
# 3.B.07 Animal contact prevalence (age standardized) (per 100 000 population) female
# 3.B.07 Animal contact prevalence (age standardized) (per 100 000 population) male
# 3.B.08 Foreign body prevalence (age standardized) (per 100 000 population) female
# 3.B.08 Foreign body prevalence (age standardized) (per 100 000 population) male
# 3.B.09 Other unintentional injuries prevalence (age standardized) (per 100 000 population) female
# 3.B.09 Other unintentional injuries prevalence (age standardized) (per 100 000 population) male
# 3.B.10 Exposure to forces of nature prevalence (age standardized) (per 100 000 population) female
# 3.B.10 Exposure to forces of nature prevalence (age standardized) (per 100 000 population) male
# 3.B.11 Environmental heat and cold exposure prevalence (age standardized) (per 100 000 population) female
# 3.B.11 Environmental heat and cold exposure prevalence (age standardized) (per 100 000 population) male
# 3.C.0 Self-harm and interpersonal violence prevalence (age standardized) (per 100 000 population) female
# 3.C.0 Self-harm and interpersonal violence prevalence (age standardized) (per 100 000 population) male
# 3.C.01 Self-harm prevalence (age standardized) (per 100 000 population) female
# 3.C.01 Self-harm prevalence (age standardized) (per 100 000 population) male
# 3.C.02 Interpersonal violence prevalence (age standardized) (per 100 000 population) female
# 3.C.02 Interpersonal violence prevalence (age standardized) (per 100 000 population) male
# 3.C.03 Executions and police conflict prevalence (age standardized) (per 100 000 population) female
# 3.C.03 Executions and police conflict prevalence (age standardized) (per 100 000 population) male
# 3.C.04 Conflict and terrorism prevalence (age standardized) (per 100 000 population) female
# 3.C.04 Conflict and terrorism prevalence (age standardized) (per 100 000 population) male
# 1.C.02 Other intestinal infectious diseases prevalence (age standardized) (per 100 000 population) female
# 1.C.02 Other intestinal infectious diseases prevalence (age standardized) (per 100 000 population) male
# 1.G.05 Other nutritional deficiencies prevalence (age standardized) (per 100 000 population) female
# 1.G.05 Other nutritional deficiencies prevalence (age standardized) (per 100 000 population) male
# 2.C.05 Other chronic respiratory diseases prevalence (age standardized) (per 100 000 population) female
# 2.C.05 Other chronic respiratory diseases prevalence (age standardized) (per 100 000 population) male
# 2.D.09 Other digestive diseases prevalence (age standardized) (per 100 000 population) female
# 2.D.09 Other digestive diseases prevalence (age standardized) (per 100 000 population) male
# Persistence to grade 5 (% of cohort) female
# Persistence to grade 5 (% of cohort) male
# Persistence to last grade of primary (% of cohort) female
# Persistence to last grade of primary (% of cohort) male
# Lower secondary completion rate (% of relevant age group) female
# Lower secondary completion rate (% of relevant age group) male
# Progression to secondary school (%) female
# Progression to secondary school (%) male
# Primary completion rate (% of relevant age group) female
# Primary completion rate (% of relevant age group) male
# Gross intake ratio in first grade of primary education (% of relevant age group) female
# Gross intake ratio in first grade of primary education (% of relevant age group) male
# School enrollment, primary (% net) female
# School enrollment, primary (% net) male
# Over-age students, primary (% of enrollment) female
# Over-age students, primary (% of enrollment) male
# Repeaters, primary (% of total enrollment) female
# Repeaters, primary (% of total enrollment) male
# Adjusted net enrollment rate, primary (% of primary school age children) female
# Adjusted net enrollment rate, primary (% of primary school age children) male
# Children out of school (% of primary school age) female
# Children out of school (% of primary school age) male
# School enrollment, secondary (% net) female
# School enrollment, secondary (% net) male
# Adolescents out of school (% of lower secondary school age) female
# Adolescents out of school (% of lower secondary school age) male
# Educational attainment, at least completed primary, population 25+ years (%) (cumulative) female
# Educational attainment, at least completed primary, population 25+ years (%) (cumulative) male
# Educational attainment, at least completed lower secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed lower secondary, population 25+ (%) (cumulative) male
# Educational attainment, at least completed post-secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed post-secondary, population 25+ (%) (cumulative) male
# Educational attainment, at least completed upper secondary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed upper secondary, population 25+ (%) (cumulative) male
# Literacy rate, youth total (% of people ages 15-24) female
# Literacy rate, youth total (% of people ages 15-24) male
# Literacy rate, adult total (% of people ages 15 and above) female
# Literacy rate, adult total (% of people ages 15 and above) male
# Employment in agriculture (% of total employment) (modeled ILO estimate) female
# Employment in agriculture (% of total employment) (modeled ILO estimate) male
# Employment to population ratio, ages 15-24 (%) (modeled ILO estimate) female
# Employment to population ratio, ages 15-24 (%) (modeled ILO estimate) male
# Employers (% of total employment) (modeled ILO estimate) female
# Employers (% of total employment) (modeled ILO estimate) male
# Self-employed, total (% of total employment) (modeled ILO estimate) female
# Self-employed, total (% of total employment) (modeled ILO estimate) male
# Employment to population ratio, 15+ (%) (modeled ILO estimate) female
# Employment to population ratio, 15+ (%) (modeled ILO estimate) male
# Vulnerable employment (% of total employment) (modeled ILO estimate) female
# Vulnerable employment (% of total employment) (modeled ILO estimate) male
# Wage and salaried workers (% of total employment) (modeled ILO estimate) female
# Wage and salaried workers (% of total employment) (modeled ILO estimate) male
# Contributing family workers (% of total employment) (modeled ILO estimate) female
# Contributing family workers (% of total employment) (modeled ILO estimate) male
# Employment in industry (% of total employment) (modeled ILO estimate) female
# Employment in industry (% of total employment) (modeled ILO estimate) male
# Labor force participation rate (% of total population ages 15-64) (modeled ILO estimate) female
# Labor force participation rate (% of total population ages 15-64) (modeled ILO estimate) male
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) female
# Labor force participation rate for ages 15-24, total (%) (modeled ILO estimate) male
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) female
# Labor force participation rate, total (% of total population ages 15+) (modeled ILO estimate) male
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) female
# Unemployment, youth total (% of total labor force ages 15-24) (modeled ILO estimate) male
# Unemployment (% of total labor force) (modeled ILO estimate) female
# Unemployment (% of total labor force) (modeled ILO estimate) male
# Net intake rate in grade 1 (% of official school-age population) female
# Net intake rate in grade 1 (% of official school-age population) male
# Children in employment, unpaid family workers (% of children in employment, ages 7-14) female
# Children in employment, unpaid family workers (% of children in employment, ages 7-14) male
# Children in employment (% of children ages 7-14) female
# Children in employment (% of children ages 7-14) male
# Children in employment, study and work (% of children in employment, ages 7-14) female
# Children in employment, study and work (% of children in employment, ages 7-14) male
# Children in employment, work only (% of children in employment, ages 7-14) female
# Children in employment, work only (% of children in employment, ages 7-14) male
# Children in employment, wage workers (% of children in employment, ages 7-14) female
# Children in employment, wage workers (% of children in employment, ages 7-14) male
# Educational attainment, at least Bachelor's or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, at least Bachelor's or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, Doctoral or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, Doctoral or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, at least Master's or equivalent, population 25+ (%) (cumulative) female
# Educational attainment, at least Master's or equivalent, population 25+ (%) (cumulative) male
# Educational attainment, at least completed short-cycle tertiary, population 25+ (%) (cumulative) female
# Educational attainment, at least completed short-cycle tertiary, population 25+ (%) (cumulative) male
# Labor force with advanced education (% of total working-age population with advanced education) female
# Labor force with advanced education (% of total working-age population with advanced education) male
# Labor force with basic education (% of total working-age population with basic education) female
# Labor force with basic education (% of total working-age population with basic education) male
# Labor force with intermediate education (% of total working-age population with intermediate education) female
# Labor force with intermediate education (% of total working-age population with intermediate education) male
# Unemployment with advanced education (% of total labor force with advanced education) female
# Unemployment with advanced education (% of total labor force with advanced education) male
# Unemployment with basic education (% of total labor force with basic education) female
# Unemployment with basic education (% of total labor force with basic education) male
# Unemployment with intermediate education (% of total labor force with intermediate education) female
# Unemployment with intermediate education (% of total labor force with intermediate education) male
# Share of youth not in education, employment or training (% of youth population) female
# Share of youth not in education, employment or training (% of youth population) male
# Child employment in agriculture (% of economically active children ages 7-14) female
# Child employment in agriculture (% of economically active children ages 7-14) male
# Child employment in manufacturing (% of economically active children ages 7-14) female
# Child employment in manufacturing (% of economically active children ages 7-14) male
# Children in employment, self-employed (% of children in employment, ages 7-14) female
# Children in employment, self-employed (% of children in employment, ages 7-14) male
# Child employment in services (% of economically active children ages 7-14) female
# Child employment in services (% of economically active children ages 7-14) male
# Trained teachers in lower secondary education (% of total teachers) female
# Trained teachers in lower secondary education (% of total teachers) male
# Trained teachers in secondary education (% of total teachers) female
# Trained teachers in secondary education (% of total teachers) male
# Trained teachers in upper secondary education (% of total teachers) female
# Trained teachers in upper secondary education (% of total teachers) male
# Trained teachers in preprimary education (% of total teachers) female
# Trained teachers in preprimary education (% of total teachers) male
# Trained teachers in primary education (% of total teachers) female
# Trained teachers in primary education (% of total teachers) male
# Land area where elevation is below 5 meters (% of total land area) rural
# Land area where elevation is below 5 meters (% of total land area) urban
# Population living in areas where elevation is below 5 meters (% of total population) rural
# Population living in areas where elevation is below 5 meters (% of total population) urban
# Coverage of social safety net programs (% of population) Quintile 1 (poorest)
# Coverage of social safety net programs (% of population) Quintile 5 (richest)
# Coverage of social insurance programs (% of population) Quintile 1 (poorest)
# Coverage of social insurance programs (% of population) Quintile 5 (richest)
# Coverage of unemployment benefits and ALMP (% of population) Quintile 1 (poorest)
# Coverage of unemployment benefits and ALMP (% of population) Quintile 5 (richest)
# income_num

# %%
test_inc = test_data_x_inc[list(useful_features)]

# %%
validation_inc_coll = {}

for fold in range(0, 5):
    val_y = validation_inc[fold][1].copy()
    val_x = validation_inc[fold][0].copy()

    vx_col = val_x.columns.intersection(list(useful_features))
    vx = val_x[vx_col]  
    validation_inc_coll[fold] = [vx, val_y]

# %%
train_inc_coll = {}

for fold in range(0, 5):
    t_y = train_inc[fold][1].copy()
    t_x = train_inc[fold][0].copy()

    tx_col = t_x.columns.intersection(list(useful_features))
    tx = t_x[tx_col]  
    train_inc_coll[fold] = [tx, t_y]

# %%
needed_thresholds = [0.85, 0.95, 1]

#fold : train_85, rows_left, col_left, train_95, rows_left, col_left, train_100, rows_left, col_left
folds_thresh_inc_coll = {0 : [], 1 : [], 2 : [], 3 : [], 4 : []}

for fold in range(0, 5):
    data_to_thresholdx = train_inc_coll[fold][0]
    data_to_thresholdy = train_inc_coll[fold][1]
    data_to_threshold = pd.concat([data_to_thresholdx, data_to_thresholdy], axis=1)
    
    for thresh in needed_thresholds:
        new_data, new_proportion, new_changes = iterative_thresholding(data_to_threshold, thresh)
        folds_thresh_inc_coll[fold].append(new_data)
        folds_thresh_inc_coll[fold].append(new_data.shape[0])
        folds_thresh_inc_coll[fold].append(new_data.shape[1])

# %% [markdown]
# #### Split by Year

# %%
test_year = test_data_x_year[list(useful_features)]

# %%
validation_year_coll = {}

for fold in range(0, 5):
    val_y = validation_year[fold][1].copy()
    val_x = validation_year[fold][0].copy()

    vx_col = val_x.columns.intersection(list(useful_features))
    vx = val_x[vx_col]  
    validation_year_coll[fold] = [vx, val_y]

# %%
train_year_coll = {}

for fold in range(0, 5):
    t_y = train_year[fold][1].copy()
    t_x = train_year[fold][0].copy()

    tx_col = t_x.columns.intersection(list(useful_features))
    tx = t_x[tx_col]  
    train_year_coll[fold] = [tx, t_y]

# %%
needed_thresholds = [0.85, 0.95, 1]

#fold : train_85, rows_left, col_left, train_95, rows_left, col_left, train_100, rows_left, col_left
folds_thresh_year_coll = {0 : [], 1 : [], 2 : [], 3 : [], 4 : []}

for fold in range(0, 5):
    data_to_thresholdx = train_year_coll[fold][0]
    data_to_thresholdy = train_year_coll[fold][1]
    data_to_threshold = pd.concat([data_to_thresholdx, data_to_thresholdy], axis=1)
    
    for thresh in needed_thresholds:
        new_data, new_proportion, new_changes = iterative_thresholding(data_to_threshold, thresh)
        folds_thresh_year_coll[fold].append(new_data)
        folds_thresh_year_coll[fold].append(new_data.shape[0])
        folds_thresh_year_coll[fold].append(new_data.shape[1])

# %% [markdown]
# ### Saving

# %%
train_filepath_inc = '../../fs_fromlit_data/income/train'
val_filepath_inc = '../../fs_fromlit_data/income/val'
test_filepath_inc = '../../fs_fromlit_data/income/test'

train_filepath_year = '../../fs_fromlit_data/year/train'
val_filepath_year = '../../fs_fromlit_data/year/val'
test_filepath_year = '../../fs_fromlit_data/year/test'

# %%
########### test set

pd.DataFrame(test_inc).to_csv(test_filepath_inc + '/X_test.csv')
pd.DataFrame(test_data_y_inc).to_csv(test_filepath_inc + '/y_test.csv')

# %%
########### test set

pd.DataFrame(test_year).to_csv(test_filepath_year + '/X_test.csv')
pd.DataFrame(test_data_y_year).to_csv(test_filepath_year + '/y_test.csv')

# %%
########### validation set

for fold in range(0, 5):
    val_input_inc = validation_inc_coll[fold][0]
    val_labels_inc = validation_inc_coll[fold][1]
    pd.DataFrame(val_input_inc).to_csv(val_filepath_inc + '/X_val_' + str(fold) + '.csv')
    pd.DataFrame(val_labels_inc).to_csv(val_filepath_inc + '/y_val_' + str(fold) + '.csv')

# %%
########### validation set

for fold in range(0, 5):
    val_input = validation_year_coll[fold][0]
    val_labels = validation_year_coll[fold][1]
    pd.DataFrame(val_input).to_csv(val_filepath_year + '/X_val_' + str(fold) + '.csv')
    pd.DataFrame(val_labels).to_csv(val_filepath_year + '/y_val_' + str(fold) + '.csv')

# %%
########### train set
threshs = ['85', '95', '1']

for fold in range(0, 5):
    for idx, thresh in enumerate(threshs):
        idx_multiple = idx*3

        data = folds_thresh_inc_coll[fold][idx_multiple]
        train_input = data.drop(['Maternal mortality ratio (national estimate, per 100,000 live births)'], axis=1)
        train_input_idx_drop = train_input.drop(columns=['index'], axis=1)
        train_labels = data[['Maternal mortality ratio (national estimate, per 100,000 live births)']]
        pd.DataFrame(train_input_idx_drop).to_csv(train_filepath_inc + '/X_train_' + str(fold) + '_' + thresh + '.csv')
        pd.DataFrame(train_labels).to_csv(train_filepath_inc + '/y_train_' + str(fold) + '_' + thresh + '.csv')

        data_year = folds_thresh_year_coll[fold][idx_multiple]
        train_input_year = data_year.drop(['Maternal mortality ratio (national estimate, per 100,000 live births)'], axis=1)
        train_input_idx_drop_year = train_input_year.drop(columns=['index'], axis=1)
        train_labels_year = data_year[['Maternal mortality ratio (national estimate, per 100,000 live births)']]
        pd.DataFrame(train_input_idx_drop_year).to_csv(train_filepath_year + '/X_train_' + str(fold) + '_' + thresh + '.csv')
        pd.DataFrame(train_labels_year).to_csv(train_filepath_year + '/y_train_' + str(fold) + '_' + thresh + '.csv')

# %%
########### train set
threshs = ['85', '95', '1']

for fold in range(0, 5):
    for idx, thresh in enumerate(threshs):
        idx_multiple = idx*3

        data_year = folds_thresh_year_coll[fold][idx_multiple]
        train_input_year = data_year.drop(['Maternal mortality ratio (national estimate, per 100,000 live births)'], axis=1)
        train_input_idx_drop_year = train_input_year.drop(columns=['index'], axis=1)
        train_labels_year = data_year[['Maternal mortality ratio (national estimate, per 100,000 live births)']]
        pd.DataFrame(train_input_idx_drop_year).to_csv(train_filepath_year + '/X_train_' + str(fold) + '_' + thresh + '.csv')
        pd.DataFrame(train_labels_year).to_csv(train_filepath_year + '/y_train_' + str(fold) + '_' + thresh + '.csv')

# %%
folds_thresh_inc_coll[0][0].shape
# Out:
# (1964, 15)

# %%
for fold in range(0, 5):
    print('income')
    print(folds_thresh_inc_coll[fold][0].shape, folds_thresh_inc_coll[fold][3].shape, folds_thresh_inc_coll[fold][6].shape)
    print('year')
    print(folds_thresh_year_coll[fold][0].shape, folds_thresh_year_coll[fold][3].shape, folds_thresh_year_coll[fold][6].shape)
# Out:
# income
# (1964, 15) (1964, 33) (1964, 42)
# year
# (2068, 15) (2068, 35) (2068, 42)
# income
# (1964, 15) (1964, 35) (1964, 42)
# year
# (2070, 15) (2070, 33) (2070, 42)
# income
# (1964, 15) (1964, 36) (1964, 42)
# year
# (2066, 15) (2066, 34) (2066, 42)
# income
# (1964, 15) (1964, 36) (1964, 42)
# year
# (2070, 15) (2070, 34) (2070, 42)
# income
# (1964, 15) (1964, 35) (1964, 42)
# year
# (2070, 15) (2070, 34) (2070, 42)

# %% [markdown]
# ### Loading Saved Datasets

# %%
filepath_income = '../../fs_fromlit_data/income'

# %%
validation_lit_country = {}

for fold in range(0, 5):
    vdata_x = pd.read_csv(filepath_income + '/val/X_val_' + str(fold) + '.csv')
    vdata_x = vdata_x.drop(columns=['Unnamed: 0'], axis=1)
    vdata_y = pd.read_csv(filepath_income + '/val/y_val_' + str(fold) + '.csv')
    vdata_y = vdata_y.drop(columns=['Unnamed: 0'], axis=1)
    validation_lit_country[fold] = [vdata_x, vdata_y]

# %%
train_lit_country = {}

for fold in range(0, 5):
    tdata_x85 = pd.read_csv(filepath_income + '/train/X_train_' + str(fold) + '_85.csv')
    tdata_x85 = tdata_x85.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y85 = pd.read_csv(filepath_income + '/train/y_train_' + str(fold) + '_85.csv')
    tdata_y85 = tdata_y85.drop(columns=['Unnamed: 0'], axis=1)

    tdata_x95 = pd.read_csv(filepath_income + '/train/X_train_' + str(fold) + '_95.csv')
    tdata_x95 = tdata_x95.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y95 = pd.read_csv(filepath_income + '/train/y_train_' + str(fold) + '_95.csv')
    tdata_y95 = tdata_y95.drop(columns=['Unnamed: 0'], axis=1)

    tdata_x1 = pd.read_csv(filepath_income + '/train/X_train_' + str(fold) + '_1.csv')
    tdata_x1 = tdata_x1.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y1 = pd.read_csv(filepath_income + '/train/y_train_' + str(fold) + '_1.csv')
    tdata_y1 = tdata_y1.drop(columns=['Unnamed: 0'], axis=1)

    train_lit_country[fold] = [tdata_x85, tdata_y85, tdata_x95, tdata_y95, tdata_x1, tdata_y1]

# %%
filepath_year = '../../fs_fromlit_data/year'

# %%
validation_lit_year = {}

for fold in range(0, 5):
    vdata_x = pd.read_csv(filepath_year + '/val/X_val_' + str(fold) + '.csv')
    vdata_x = vdata_x.drop(columns=['Unnamed: 0'], axis=1)
    vdata_y = pd.read_csv(filepath_year + '/val/y_val_' + str(fold) + '.csv')
    vdata_y = vdata_y.drop(columns=['Unnamed: 0'], axis=1)
    validation_lit_year[fold] = [vdata_x, vdata_y]

# %%
train_lit_year = {}

for fold in range(0, 5):
    tdata_x85 = pd.read_csv(filepath_year + '/train/X_train_' + str(fold) + '_85.csv')
    tdata_x85 = tdata_x85.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y85 = pd.read_csv(filepath_year + '/train/y_train_' + str(fold) + '_85.csv')
    tdata_y85 = tdata_y85.drop(columns=['Unnamed: 0'], axis=1)

    tdata_x95 = pd.read_csv(filepath_year + '/train/X_train_' + str(fold) + '_95.csv')
    tdata_x95 = tdata_x95.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y95 = pd.read_csv(filepath_year + '/train/y_train_' + str(fold) + '_95.csv')
    tdata_y95 = tdata_y95.drop(columns=['Unnamed: 0'], axis=1)

    tdata_x1 = pd.read_csv(filepath_year + '/train/X_train_' + str(fold) + '_1.csv')
    tdata_x1 = tdata_x1.drop(columns=['Unnamed: 0'], axis=1)
    tdata_y1 = pd.read_csv(filepath_year + '/train/y_train_' + str(fold) + '_1.csv')
    tdata_y1 = tdata_y1.drop(columns=['Unnamed: 0'], axis=1)

    train_lit_year[fold] = [tdata_x85, tdata_y85, tdata_x95, tdata_y95, tdata_x1, tdata_y1]

# %% [markdown]
# ## LightGBM

# %%
def objective(trial, x_train, y_train, x_val, y_val):

    n_trees = trial.suggest_int("number_trees", 10, 300)

    max_depth = trial.suggest_int("max_tree_depth", 3, 25)

    boosting_type = trial.suggest_categorical("boosting_type", ['gbdt', 'dart'])
    
    bagging_fraction = trial.suggest_float("bagging_fraction", 0.1, 1.0)
    bagging_freq = trial.suggest_int("bagging_freq", 0, 10)

    learning_rate = trial.suggest_float("learning_rate", 0, 1)
    l1_norm = trial.suggest_float("l1_norm", 0, 0.001)
    l2_norm = trial.suggest_float("l2_norm", 0, 0.001)

    lgbm_model = lgb.LGBMRegressor(random_state=42, verbosity = -1, n_estimators=n_trees, boosting=boosting_type, max_depth=max_depth, learning_rate=learning_rate, reg_alpha=l1_norm, reg_lambda=l2_norm, bagging_fraction=bagging_fraction, bagging_freq=bagging_freq)
    trained_model = lgbm_model.fit(x_train, y_train)
    y_pred = trained_model.predict(x_val)
    val_loss = mean_squared_error(y_pred, y_val)

    return val_loss  # Optuna minimizes this

# %% [markdown]
# ### LightGBM by Country

# %%
output_dir_inc = '../../fs_fromlit_models/income/lightgbm'

# %%
for fold in range(0, 5):
        val_input_data = validation_lit_country[fold][0].copy()
        #because lightgbm cannot handle the comma
        val_input_data.columns = val_input_data.columns.str.replace(r'[\"\[\]\{\}\\:,]', '', regex=True)
        val_input_data['setting'] = val_input_data['setting'].astype("category")
        val_label = validation_lit_country[fold][1].copy()
        val_label.column = 'Maternal mortality ratio (national estimate per 100000 live births)'

        for thresh_idx, thresh in enumerate(['85', '95', '1']):
            train_input_data = train_lit_country[fold][thresh_idx * 2].copy()
            train_input_data['setting'] = train_input_data['setting'].astype("category")
            train_input_data.columns = train_input_data.columns.str.replace(r'[\"\[\]\{\}\\:,]', '', regex=True)

            train_label = train_lit_country[fold][thresh_idx * 2 + 1].copy()
            train_label.column = 'Maternal mortality ratio (national estimate per 100000 live births)'

            columns_needed = val_input_data.columns.intersection(train_input_data.columns)
            val_relevant_input = val_input_data[columns_needed]

            #Create a study object and optimize the objective function.
            study = optuna.create_study(direction='minimize')
            study.optimize(lambda trial: objective(trial, train_input_data, train_label, val_relevant_input, val_label), n_trials=300)
            best_model = lgb.LGBMRegressor(**study.best_params)
            best_model.fit(train_input_data, train_label)

            #save best model 
            joblib.dump(best_model, output_dir_inc + '/best_model_' + str(fold) + '_' + thresh +  '.pkl')
            joblib.dump(study.best_params, f"{output_dir_inc}/best_params_{fold}_{thresh}.pkl")

            # Save study for later visualization
            joblib.dump(study, f"{output_dir_inc}/optuna_study_{fold}_{thresh}.pkl")

            summary = {
                "dataset": str(fold) + '_' + thresh,
                "fold" : fold,
                "threshold": thresh,
                "model": 'lightgbm',
                "best_params": study.best_params,
                "best_optuna_loss": study.best_value
            }

            with open(f"{output_dir_inc}/results_{fold}_{thresh}.json", "w") as f:
                json.dump(summary, f, indent=2)
# Out:
# [I 2025-08-10 12:41:34,151] A new study created in memory with name: no-name-2d1bc111-71f5-418b-b4b6-6bf601e5d8a9
# [I 2025-08-10 12:41:34,241] Trial 0 finished with value: 10670.642440947368 and parameters: {'number_trees': 22, 'max_tree_depth': 8, 'boosting_type': 'gbdt', 'bagging_fraction': 0.4090397056954012, 'bagging_freq': 2, 'learning_rate': 0.4959951315949911, 'l1_norm': 0.0005253928117187177, 'l2_norm': 0.0007866744033898418}. Best is trial 0 with value: 10670.642440947368.
# [I 2025-08-10 12:41:34,328] Trial 1 finished with value: 8565.570283457295 and parameters: {'number_trees': 52, 'max_tree_depth': 3, 'boosting_type': 'gbdt', 'bagging_fraction': 0.5746923663342927, 'bagging_freq': 2, 'learning_rate': 0.06330548774609801, 'l1_norm': 0.0003790820123838412, 'l2_norm': 0.0005065034271646862}. Best is trial 1 with value: 8565.570283457295.
# [I 2025-08-10 12:41:38,064] Trial 2 finished with value: 9534.223354365953 and parameters: {'number_trees': 300, 'max_tree_depth': 14, 'boosting_type': 'gbdt', 'bagging_fraction': 0.5313680362543426, 'bagging_freq': 7, 'learning_rate': 0.052534107127524265, 'l1_norm': 3.8114330123872996e-05, 'l2_norm': 0.0005675016011383389}. Best is trial 1 with value: 8565.570283457295.
# [I 2025-08-10 12:41:41,292] Trial 3 finished with value: 9008.26736706773 and parameters: {'number_trees': 216, 'max_tree_depth': 22, 'boosting_type': 'gbdt', 'bagging_fraction': 0.8172210315310589, 'bagging_freq': 9, 'learning_rate': 0.5276135602484024, 'l1_norm': 0.0003619111655414149, 'l2_norm': 0.00035785705091799915}. Best is trial 1 with value: 8565.570283457295.
# [I 2025-08-10 12:41:41,563] Trial 4 finished with value: 9161.561603584607 and parameters: {'number_trees': 24, 'max_tree_depth': 24, 'boosting_type': 'gbdt', 'bagging_fraction': 0.9447613426529275, 'bagging_freq': 10, 'learning_rate': 0.6354339493986183, 'l1_norm': 0.00016064269620453552, 'l2_norm': 0.0008572346610738863}. Best is trial 1 with value: 8565.570283457295.
# [I 2025-08-10 13:58:05,838] Trial 298 finished with value: 5282.768448189366 and parameters: {'number_trees': 134, 'max_tree_depth': 4, 'boosting_type': 'gbdt', 'bagging_fraction': 0.7635119963772754, 'bagging_freq': 5, 'learning_rate': 0.3642242068845585, 'l1_norm': 0.0009471753915541531, 'l2_norm': 0.00045190704975277756}. Best is trial 284 with value: 4724.84233660057.
# [I 2025-08-10 13:58:06,071] Trial 299 finished with value: 5170.898805029823 and parameters: {'number_trees': 131, 'max_tree_depth': 4, 'boosting_type': 'gbdt', 'bagging_fraction': 0.760620989743218, 'bagging_freq': 5, 'learning_rate': 0.36001095099830743, 'l1_norm': 0.0009472866862233917, 'l2_norm': 0.00045496701517815075}. Best is trial 284 with value: 4724.84233660057.

# %% [markdown]
# ### LightGBM by Year

# %%
output_dir_year = '../../fs_fromlit_models/year/lightgbm'

# %%
for fold in range(0, 5):
        val_input_data = validation_lit_year[fold][0].copy()
        #because lightgbm cannot handle the comma
        val_input_data.columns = val_input_data.columns.str.replace(r'[\"\[\]\{\}\\:,]', '', regex=True)
        val_input_data['setting'] = val_input_data['setting'].astype("category")
        val_label = validation_lit_year[fold][1].copy()
        val_label.column = 'Maternal mortality ratio (national estimate per 100000 live births)'

        for thresh_idx, thresh in enumerate(['85', '95', '1']):
            train_input_data = train_lit_year[fold][thresh_idx * 2].copy()
            train_input_data['setting'] = train_input_data['setting'].astype("category")
            train_input_data.columns = train_input_data.columns.str.replace(r'[\"\[\]\{\}\\:,]', '', regex=True)

            train_label = train_lit_year[fold][thresh_idx * 2 + 1].copy()
            train_label.column = 'Maternal mortality ratio (national estimate per 100000 live births)'

            columns_needed = val_input_data.columns.intersection(train_input_data.columns)
            val_relevant_input = val_input_data[columns_needed]

            #Create a study object and optimize the objective function.
            study = optuna.create_study(direction='minimize')
            study.optimize(lambda trial: objective(trial, train_input_data, train_label, val_relevant_input, val_label), n_trials=300)
            best_model = lgb.LGBMRegressor(**study.best_params)
            best_model.fit(train_input_data, train_label)

            #save best model 
            joblib.dump(best_model, output_dir_year + '/best_model_' + str(fold) + '_' + thresh +  '.pkl')
            joblib.dump(study.best_params, f"{output_dir_year}/best_params_{fold}_{thresh}.pkl")

            # Save study for later visualization
            joblib.dump(study, f"{output_dir_year}/optuna_study_{fold}_{thresh}.pkl")

            summary = {
                "dataset": str(fold) + '_' + thresh,
                "fold" : fold,
                "threshold": thresh,
                "model": 'lightgbm',
                "best_params": study.best_params,
                "best_optuna_loss": study.best_value
            }

            with open(f"{output_dir_year}/results_{fold}_{thresh}.json", "w") as f:
                json.dump(summary, f, indent=2)
# Out:
# [I 2025-08-10 13:58:07,191] A new study created in memory with name: no-name-e6be1af3-7dda-4c83-87e3-f39c56d2eff4
# [I 2025-08-10 13:58:07,381] Trial 0 finished with value: 4402.328935167294 and parameters: {'number_trees': 39, 'max_tree_depth': 25, 'boosting_type': 'dart', 'bagging_fraction': 0.8098567612297991, 'bagging_freq': 8, 'learning_rate': 0.6817046838102404, 'l1_norm': 0.0006807423771225078, 'l2_norm': 0.0004960791354674878}. Best is trial 0 with value: 4402.328935167294.
# [I 2025-08-10 15:43:24,956] Trial 260 finished with value: 3098.196517284911 and parameters: {'number_trees': 103, 'max_tree_depth': 20, 'boosting_type': 'dart', 'bagging_fraction': 0.8517574671072856, 'bagging_freq': 0, 'learning_rate': 0.7466716545784579, 'l1_norm': 0.00031372363060441663, 'l2_norm': 0.00046493478487121123}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:25,793] Trial 261 finished with value: 3496.264904078813 and parameters: {'number_trees': 112, 'max_tree_depth': 14, 'boosting_type': 'dart', 'bagging_fraction': 0.9823472460755047, 'bagging_freq': 0, 'learning_rate': 0.7471967943051342, 'l1_norm': 0.0003390365875843361, 'l2_norm': 0.0004155402733573174}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:26,758] Trial 262 finished with value: 3538.3167843691394 and parameters: {'number_trees': 102, 'max_tree_depth': 19, 'boosting_type': 'dart', 'bagging_fraction': 0.9138177565070963, 'bagging_freq': 0, 'learning_rate': 0.7260402218516485, 'l1_norm': 0.0009043335947194751, 'l2_norm': 0.00043593928389726116}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:27,652] Trial 263 finished with value: 3398.8306657541434 and parameters: {'number_trees': 107, 'max_tree_depth': 20, 'boosting_type': 'dart', 'bagging_fraction': 0.8944706979528029, 'bagging_freq': 0, 'learning_rate': 0.7648296586695572, 'l1_norm': 0.0008611025783485004, 'l2_norm': 0.000462403710692024}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:28,333] Trial 264 finished with value: 4033.142358623445 and parameters: {'number_trees': 104, 'max_tree_depth': 13, 'boosting_type': 'dart', 'bagging_fraction': 0.8463657219007221, 'bagging_freq': 1, 'learning_rate': 0.7442882201474983, 'l1_norm': 0.00032135928784384095, 'l2_norm': 0.0004050267879062916}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:29,241] Trial 265 finished with value: 4840.703681415577 and parameters: {'number_trees': 97, 'max_tree_depth': 20, 'boosting_type': 'gbdt', 'bagging_fraction': 0.928524999054025, 'bagging_freq': 0, 'learning_rate': 0.7593734412219024, 'l1_norm': 0.00015448108671676353, 'l2_norm': 0.00048607609024661167}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:30,124] Trial 266 finished with value: 3720.922635459562 and parameters: {'number_trees': 114, 'max_tree_depth': 21, 'boosting_type': 'dart', 'bagging_fraction': 0.9558142796802326, 'bagging_freq': 8, 'learning_rate': 0.732025166170861, 'l1_norm': 0.0004778145918001024, 'l2_norm': 0.000715855496850546}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:32,577] Trial 267 finished with value: 5539.542894007778 and parameters: {'number_trees': 195, 'max_tree_depth': 20, 'boosting_type': 'dart', 'bagging_fraction': 0.2791655616723727, 'bagging_freq': 3, 'learning_rate': 0.7772669397456218, 'l1_norm': 0.0003981692717218377, 'l2_norm': 0.00046197765964089586}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:40,613] Trial 276 finished with value: 4317.352872512536 and parameters: {'number_trees': 94, 'max_tree_depth': 14, 'boosting_type': 'dart', 'bagging_fraction': 0.8588629438512774, 'bagging_freq': 5, 'learning_rate': 0.7583609942244768, 'l1_norm': 0.0004154952053201092, 'l2_norm': 0.0004520542444910148}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:41,398] Trial 277 finished with value: 4030.4182028882196 and parameters: {'number_trees': 101, 'max_tree_depth': 15, 'boosting_type': 'gbdt', 'bagging_fraction': 0.9658690779843803, 'bagging_freq': 0, 'learning_rate': 0.7884605940807885, 'l1_norm': 0.0004941680314687405, 'l2_norm': 0.00040830957098086376}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:43,270] Trial 278 finished with value: 3517.3688984319733 and parameters: {'number_trees': 190, 'max_tree_depth': 18, 'boosting_type': 'dart', 'bagging_fraction': 0.8244808168204922, 'bagging_freq': 0, 'learning_rate': 0.8245715878476746, 'l1_norm': 0.00017794038160218688, 'l2_norm': 0.0004994031527332963}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:43,793] Trial 279 finished with value: 3706.493193986795 and parameters: {'number_trees': 82, 'max_tree_depth': 13, 'boosting_type': 'dart', 'bagging_fraction': 0.9993922422603873, 'bagging_freq': 0, 'learning_rate': 0.845593660010362, 'l1_norm': 0.0003851365981441062, 'l2_norm': 0.0005188084154917285}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:44,495] Trial 280 finished with value: 3863.656806969239 and parameters: {'number_trees': 89, 'max_tree_depth': 16, 'boosting_type': 'dart', 'bagging_fraction': 0.8067424023778829, 'bagging_freq': 0, 'learning_rate': 0.8025720693426862, 'l1_norm': 0.0005219729246920125, 'l2_norm': 0.00047422915884657923}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:45,039] Trial 281 finished with value: 7551.7742324745905 and parameters: {'number_trees': 69, 'max_tree_depth': 15, 'boosting_type': 'dart', 'bagging_fraction': 0.8760278239253632, 'bagging_freq': 0, 'learning_rate': 0.04473306790980203, 'l1_norm': 0.0004680913231975963, 'l2_norm': 0.00043912589617830936}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:45,937] Trial 282 finished with value: 6462.5791206369895 and parameters: {'number_trees': 113, 'max_tree_depth': 17, 'boosting_type': 'dart', 'bagging_fraction': 0.5746776726272984, 'bagging_freq': 1, 'learning_rate': 0.7650409019380744, 'l1_norm': 0.00042456852598424705, 'l2_norm': 0.0004889620559973931}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:47,571] Trial 283 finished with value: 3707.1779537758903 and parameters: {'number_trees': 220, 'max_tree_depth': 10, 'boosting_type': 'dart', 'bagging_fraction': 0.9219101915924403, 'bagging_freq': 0, 'learning_rate': 0.7267642866546853, 'l1_norm': 0.00012531248085088494, 'l2_norm': 0.0007093699165395301}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:48,165] Trial 284 finished with value: 3477.185473121384 and parameters: {'number_trees': 86, 'max_tree_depth': 16, 'boosting_type': 'dart', 'bagging_fraction': 0.8558669094157679, 'bagging_freq': 0, 'learning_rate': 0.8203209798987446, 'l1_norm': 0.000442360108148792, 'l2_norm': 0.00045852614716016487}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:49,243] Trial 285 finished with value: 3171.9849767171436 and parameters: {'number_trees': 120, 'max_tree_depth': 18, 'boosting_type': 'dart', 'bagging_fraction': 0.9750242643226985, 'bagging_freq': 0, 'learning_rate': 0.6388876582463836, 'l1_norm': 0.0008393789974500029, 'l2_norm': 0.0005443259344211609}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:50,335] Trial 286 finished with value: 3714.8506149976097 and parameters: {'number_trees': 116, 'max_tree_depth': 18, 'boosting_type': 'dart', 'bagging_fraction': 0.9761565759898134, 'bagging_freq': 0, 'learning_rate': 0.5959634488227079, 'l1_norm': 0.0007984856945703838, 'l2_norm': 0.0005511467737386364}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:51,407] Trial 287 finished with value: 3273.3054921737785 and parameters: {'number_trees': 108, 'max_tree_depth': 18, 'boosting_type': 'dart', 'bagging_fraction': 0.40664306883107576, 'bagging_freq': 0, 'learning_rate': 0.6249325091070755, 'l1_norm': 0.000885545812636872, 'l2_norm': 0.0005243668659968396}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:52,467] Trial 288 finished with value: 3287.9580203495416 and parameters: {'number_trees': 123, 'max_tree_depth': 19, 'boosting_type': 'dart', 'bagging_fraction': 0.3835276102194702, 'bagging_freq': 0, 'learning_rate': 0.6185682129040478, 'l1_norm': 0.0008468755781125059, 'l2_norm': 0.0005382418720350936}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:53,417] Trial 289 finished with value: 3481.928947980911 and parameters: {'number_trees': 119, 'max_tree_depth': 19, 'boosting_type': 'gbdt', 'bagging_fraction': 0.3711635952162438, 'bagging_freq': 0, 'learning_rate': 0.6342666085452426, 'l1_norm': 0.0008422966521550442, 'l2_norm': 0.0005628200663038706}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:53,817] Trial 290 finished with value: 5570.098345588754 and parameters: {'number_trees': 120, 'max_tree_depth': 19, 'boosting_type': 'dart', 'bagging_fraction': 0.1455966865306652, 'bagging_freq': 6, 'learning_rate': 0.6145135639491521, 'l1_norm': 0.0008852110920355644, 'l2_norm': 0.0005811658892641415}. Best is trial 241 with value: 2961.3621856462346.
# [I 2025-08-10 15:43:54,822] Trial 291 finished with value: 3177.1602362977437 and parameters: {'number_trees': 108, 'max_tree_depth': 19, 'boosting_type': 'dart', 'bagging_fraction': 0.41358845816601475, 'bagging_freq': 0, 'learning_rate': 0.6468678178990399, 'l1_norm': 0.0008656114520757665, 'l2_norm': 0.0005234406922592389}. Best is trial 241 with value: 2961.3621856462346.
